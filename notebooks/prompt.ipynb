# %% [markdown]
# # 1. Data and Dependencies

# %% [markdown]
# ## 1.0. Dependencies

# %%
import os 
import gzip
import json
import networkx
import numpy as np
from scipy import sparse
import pandas as pd
import urllib.request 
import zipfile

# %% [markdown]
# ## 1.1. Paths

# %%
project_dir = os.path.dirname(os.getcwd()) 
data_dir = os.path.join(project_dir, "data") 
lookups_dir = os.path.join(project_dir, "lookups") 
graphs_dir = os.path.join(project_dir, "graph")

# %% [markdown]
# ## 1.2. Fetch data

# %%
def fetch_and_extract_zip(zip_path, download_url, extract_to=None, extract=False, rm_zip=False, gdrive=True): 
    """
    Check for a ZIP file at 'zip_path'. 
        If not present, download from 'download_url', and extract to 'extract_to' (default to the same directory as zip_path).
    Parameters: 
        zip_path (str): Full path to the local ZIP file. 
        download_url (str): URL to download the ZIP file from if not present.
        extract_to (str): Directory to extract the contest to (optional). 
        extract (bool): If False (default), keep the raw zip file. 
            If True, extract contents.
            Raw data should not be extracted but kept as zip file to be parsed directly on the fly. 
            Other data structures should generally be extracted. 
        gdrive (bool): True (default) if downloading from Google Drive folder.
        """
    # Set default extraction path to same directory as ZIP file 
    if extract_to is None: 
        extract_to = os.path.splitext(zip_path)[0] 

    # Check if zip already exists 
    if not os.path.exists(zip_path): 
        print(f"File not found at {zip_path}. Downloading from {download_url} ...") 
        os.makedirs(os.path.dirname(zip_path), exist_ok=True)
        if gdrive: 
            try: 
                import gdown 
            except ImportError: 
                raise ImportError("Please install gdown with pip install gdown.")
            if "drive.google.com" in download_url:
                gdown.download(download_url, zip_path, quiet=False) 
            else: 
                gdown.download(f"https://drive.google.com/uc?id={download_url}", zip_path, quiet=False)
        else:
            urllib.request.urlretrieve(download_url, zip_path) 
            
        print(f"Downloaded to {zip_path}") 
    else: 
        print(f"File already exists at {zip_path}") 
        return
    
    # Extract
    if extract: 
        print(f"Extracting ZIP to {extract_to}...") 
        with zipfile.ZipFile(zip_path, 'r') as zip_ref: 
            zip_ref.extractall(extract_to) 
        print("Extraction complete.") 
    
    if rm_zip: 
        try: 
            os.remove(zip_path) 
            print(f"Deleted ZIP file at {zip_path}")
        except OSError as e: 
            print(f"Error deleting ZIP file: {e}")

# %% [markdown]
# ### 1.2.1 Graph

# %%
os.listdir(graphs_dir)
# Out:
# ['graph.pkl',
#  'graphs.zip',
#  'graph_2.pkl',
#  'graph_3.pkl',
#  'graph_3.zip',
#  'graph_gemini-5shot.pkl',
#  'graph_gemini-5shot.zip']

# %%
graphs_url = r"https://drive.google.com/drive/folders/18SRrV1yxC9yBGbAGXCVBlBTIWkxA9rG4"
graph_zip_path = os.path.join(graphs_dir, "graph_3.zip") 
fetch_and_extract_zip(graph_zip_path, graphs_url, extract=True, extract_to=graphs_dir, rm_zip=True, gdrive=True)
# Out:
# File already exists at c:\Users\bened\DataScience\Autumn 2025\SINA\assignments\3\graph\graph_3.zip

# %% [markdown]
# Reload graph

# %%
import pickle  

graph_path = os.path.join(graphs_dir, "graph_3.pkl") 
with open(graph_path, 'rb') as f: 
    G = pickle.load(f)

# %% [markdown]
# Sanity Check

# %%
user_nodes = [
    n for n, d in G.nodes(data=True) if d.get('bipartite') == 'user'
]
review_counts = {user: G.out_degree(user) for user in user_nodes} 
sorted_reviewers = sorted(
    review_counts.items(), key=lambda x: x[1], reverse=True
)
for user, count in sorted_reviewers[:10]: 
    print(f"User {user} wrote {count} reviews")
# Out:
# User A2NYK9KWFMJV4Y wrote 229 reviews
# User A396ELNTQDFYPO wrote 165 reviews
# User A3YVD62FSVIUJ wrote 160 reviews
# User ADH0O8UVJOT10 wrote 133 reviews
# User A2SUG35F6A6S3C wrote 105 reviews
# User AZV2U6GU5QA6C wrote 95 reviews
# User A1SD1C8XK3Z3V1 wrote 94 reviews
# User A15TYOEWBQYF0X wrote 94 reviews
# User A1FOXJ8TMYVKRK wrote 92 reviews
# User ALHC64J88LVWO wrote 88 reviews

# %%
top10_degree_users = [] 
for user, _ in sorted_reviewers[:10]: 
    top10_degree_users.append(user) 
print(top10_degree_users)
# Out:
# ['A2NYK9KWFMJV4Y', 'A396ELNTQDFYPO', 'A3YVD62FSVIUJ', 'ADH0O8UVJOT10', 'A2SUG35F6A6S3C', 'AZV2U6GU5QA6C', 'A1SD1C8XK3Z3V1', 'A15TYOEWBQYF0X', 'A1FOXJ8TMYVKRK', 'ALHC64J88LVWO']

# %%
product_nodes = [
    n for n, d in G.nodes(data=True) if d.get('bipartite') == 'product'
]
review_counts = {p: G.in_degree(p) for p in product_nodes} 
product_reviews_sorted = sorted(
    review_counts.items(), key=lambda x: x[1], reverse=True
)
for product, count in product_reviews_sorted[:10]: 
    print(f"Product {product} was reviewed {count} times")
# Out:
# Product B0002H03YY was reviewed 1771 times
# Product B0006LOBA8 was reviewed 1768 times
# Product B0002H05BA was reviewed 1766 times
# Product B0002E3CK4 was reviewed 1760 times
# Product B0002E1G5C was reviewed 1387 times
# Product B0002E1NNC was reviewed 1382 times
# Product B0002E1NWI was reviewed 1379 times
# Product B0002H0A3S was reviewed 1196 times
# Product B0007Y09VO was reviewed 1178 times
# Product B004XNK7AI was reviewed 1092 times

# %% [markdown]
# ### 1.2.2. Lookup Tables

# %%
os.listdir(lookups_dir)
# Out:
# ['item_similarity_matrix.npz',
#  'lookups.zip',
#  'prediction_matrix.npz',
#  'product_index.npy',
#  'top5_recs.json',
#  'user_index.npy',
#  'user_similarity_matrix.npz',
#  'utility_matrix.npz']

# %%
lookups_url = r"https://drive.google.com/file/d/13JynWjuvIOQYLXJgJamR5OatkN0dL-h8/view?usp=drive_link" 
lookups_zip_path = os.path.join(lookups_dir, "lookups.zip") 
fetch_and_extract_zip(lookups_zip_path, lookups_url, extract_to=lookups_dir, extract=True, rm_zip=True, gdrive=True)
# Out:
# File already exists at c:\Users\bened\DataScience\Autumn 2025\SINA\assignments\3\lookups\lookups.zip

# %% [markdown]
# #### 1.2.2.1. Indexes

# %%
product_index = np.load(os.path.join(lookups_dir, "product_index.npy"), allow_pickle=True) 
user_index = np.load(os.path.join(lookups_dir, "user_index.npy"), allow_pickle=True)

# %% [markdown]
# #### 1.2.2.2. Utility Matrix

# %% [markdown]
# ground-truth: actual review data.  Between 1 and 5.  users x products

# %%
U_sparse = sparse.load_npz(os.path.join(lookups_dir, "utility_matrix.npz"))

U = pd.DataFrame.sparse.from_spmatrix(
    U_sparse, 
    index=product_index, 
    columns=user_index 
)
U.head()
# Out:
#             A0072193KFP6LUHKEXLT  A0096681Y127OL1H8W3U  A0103849GBVWICKXD4T6  \
# 0739079891                     0                     0                     0
# 0786615206                     0                     0                     0
# 1480360295                     0                     0                     0
# 1928571018                     0                     0                     0
# 9792372326                     0                     0                     0
#
#             A0279100VZXR9A2495P4  A0600727NK5MAF66IOY5  A0727497OR0PPNFLFPDV  \
# 0739079891                     0                     0                     0
# 0786615206                     0                     0                     0
# 1480360295                     0                     0                     0
# 1928571018                     0                     0                     0
# 9792372326                     0                     0                     0
#
#             A07936821FOVJO6NP4Q8  A0833006NJW9KRF77ZFY  A0955928C2RRWOWZN7UC  \
# 0739079891                     0                     0                     0
# 0786615206                     0                     0                     0
# 1480360295                     0                     0                     0
# 1928571018                     0                     0                     0
# 9792372326                     0                     0                     0
#
#             A10044ECXDUVKS  ...  AZYCGMFCK9AIM  AZYJTD9J82V5I  AZYP4FQ2L2C4O  \
# 0739079891               0  ...              0              0              0
# 0786615206               0  ...              0              0              0
# 1480360295               0  ...              0              0              0
# 1928571018               0  ...              0              0              0
# 9792372326               0  ...              0              0              0
#
#             AZZ3WYDJ0XNZW  AZZCLFV6V8693  AZZM5MUOG0LRK  AZZT9G4MJFCHD  \
# 0739079891              0              0              0              0
# 0786615206              0              0              0              0
# 1480360295              0              0              0              0
# 1928571018              0              0              0              0
# 9792372326              0              0              0              0
#
#             AZZX23UGJGKTT  AZZZ3LGTCGUZF  AZZZG8PGB1FS0
# 0739079891              0              0              0
# 0786615206              0              0              0
# 1480360295              0              0              0
# 1928571018              0              0              0
# 9792372326              0              0              0
#
# [5 rows x 27530 columns]

# %% [markdown]
# Sanity Check

# %%
# U_dense = U.sparse.to_dense() 

# ratings_counts = (U_dense > 0).sum(axis=0)
# ratings_counts_summary = ratings_counts.sort_values(ascending=False).reset_index() 
# ratings_counts_summary.columns = ['User', 'Number of actual ratings']
# ratings_counts_summary

# %%
# del U_dense

# %% [markdown]
# #### 1.2.2.3. User-Similarity Matrix

# %% [markdown]
# Users x Users. Cosine similarity. Value between 0 and 1 that tracks similarity between two users.

# %%
S_sparse = sparse.load_npz(os.path.join(lookups_dir, "user_similarity_matrix.npz")) 

S = pd.DataFrame.sparse.from_spmatrix(
    S_sparse, 
    index=user_index,
    columns=user_index
)
S.head()
# Out:
#                       A0072193KFP6LUHKEXLT  A0096681Y127OL1H8W3U  \
# A0072193KFP6LUHKEXLT                   1.0                     0
# A0096681Y127OL1H8W3U                     0                   1.0
# A0103849GBVWICKXD4T6                     0                     0
# A0279100VZXR9A2495P4                     0                     0
# A0600727NK5MAF66IOY5                     0                     0
#
#                       A0103849GBVWICKXD4T6  A0279100VZXR9A2495P4  \
# A0072193KFP6LUHKEXLT                     0                     0
# A0096681Y127OL1H8W3U                     0                     0
# A0103849GBVWICKXD4T6                   1.0                     0
# A0279100VZXR9A2495P4                     0                   1.0
# A0600727NK5MAF66IOY5                     0                     0
#
#                       A0600727NK5MAF66IOY5  A0727497OR0PPNFLFPDV  \
# A0072193KFP6LUHKEXLT                     0                     0
# A0096681Y127OL1H8W3U                     0                     0
# A0103849GBVWICKXD4T6                     0                     0
# A0279100VZXR9A2495P4                     0                     0
# A0600727NK5MAF66IOY5                   1.0                     0
#
#                       A07936821FOVJO6NP4Q8  A0833006NJW9KRF77ZFY  \
# A0072193KFP6LUHKEXLT                     0                     0
# A0096681Y127OL1H8W3U                     0                     0
# A0103849GBVWICKXD4T6                     0                     0
# A0279100VZXR9A2495P4                     0                     0
# A0600727NK5MAF66IOY5                     0                     0
#
#                       A0955928C2RRWOWZN7UC  A10044ECXDUVKS  ...  \
# A0072193KFP6LUHKEXLT                     0               0  ...
# A0096681Y127OL1H8W3U                     0               0  ...
# A0103849GBVWICKXD4T6                     0               0  ...
# A0279100VZXR9A2495P4                     0               0  ...
# A0600727NK5MAF66IOY5                     0               0  ...
#
#                       AZYCGMFCK9AIM  AZYJTD9J82V5I  AZYP4FQ2L2C4O  \
# A0072193KFP6LUHKEXLT              0              0              0
# A0096681Y127OL1H8W3U              0              0              0
# A0103849GBVWICKXD4T6              0              0              0
# A0279100VZXR9A2495P4              0              0              0
# A0600727NK5MAF66IOY5              0              0              0
#
#                       AZZ3WYDJ0XNZW  AZZCLFV6V8693  AZZM5MUOG0LRK  \
# A0072193KFP6LUHKEXLT              0              0              0
# A0096681Y127OL1H8W3U              0              0              0
# A0103849GBVWICKXD4T6              0              0              0
# A0279100VZXR9A2495P4              0              0       0.161796
# A0600727NK5MAF66IOY5              0              0              0
#
#                       AZZT9G4MJFCHD  AZZX23UGJGKTT  AZZZ3LGTCGUZF  \
# A0072193KFP6LUHKEXLT              0              0              0
# A0096681Y127OL1H8W3U              0              0              0
# A0103849GBVWICKXD4T6              0              0              0
# A0279100VZXR9A2495P4              0              0              0
# A0600727NK5MAF66IOY5              0              0              0
#
#                       AZZZG8PGB1FS0
# A0072193KFP6LUHKEXLT        0.14602
# A0096681Y127OL1H8W3U              0
# A0103849GBVWICKXD4T6              0
# A0279100VZXR9A2495P4              0
# A0600727NK5MAF66IOY5              0
#
# [5 rows x 27530 columns]

# %% [markdown]
# #### 1.2.2.4. Item-Similarity Matrix

# %% [markdown]
# Item x Item

# %%
I_sparse = sparse.load_npz(os.path.join(lookups_dir, "item_similarity_matrix.npz")) 

I = pd.DataFrame.sparse.from_spmatrix(
    I_sparse, 
    index=product_index, 
    columns=product_index 
)
I.head()
# Out:
#             0739079891  0786615206  1480360295  1928571018  9792372326  \
# 0739079891         1.0           0    0.037687           0           0
# 0786615206           0         1.0           0           0           0
# 1480360295    0.037687           0         1.0           0           0
# 1928571018           0           0           0         1.0           0
# 9792372326           0           0           0           0         1.0
#
#             B00000J50W  B00001W0DH  B00001W0DT  B00004TT3S  B00004UE29  ...  \
# 0739079891           0           0           0           0           0  ...
# 0786615206           0           0           0           0           0  ...
# 1480360295           0           0           0           0           0  ...
# 1928571018           0           0           0           0           0  ...
# 9792372326           0           0           0           0           0  ...
#
#             B01HECB4AG  B01HED0HO4  B01HG0FXAI  B01HG293XO  B01HGLUP14  \
# 0739079891           0           0           0           0           0
# 0786615206           0           0           0           0           0
# 1480360295           0           0           0           0           0
# 1928571018           0           0           0           0           0
# 9792372326           0           0           0           0           0
#
#             B01HHJXKRG  B01HHZAU3W  B01HI1VM28  B01HI5M4GW  B01HIDOPP2
# 0739079891           0           0           0           0           0
# 0786615206           0           0           0           0           0
# 1480360295           0           0           0           0           0
# 1928571018           0           0           0           0           0
# 9792372326           0           0           0           0           0
#
# [5 rows x 10620 columns]

# %% [markdown]
# #### 1.2.2.5. Prediction Matrix

# %%
P_sparse = sparse.load_npz(os.path.join(lookups_dir, "prediction_matrix.npz")) 

P = pd.DataFrame.sparse.from_spmatrix(
    P_sparse, 
    index=product_index,
    columns=user_index
)
P.head()
# Out:
#             A0072193KFP6LUHKEXLT  A0096681Y127OL1H8W3U  A0103849GBVWICKXD4T6  \
# 0739079891              0.001417              0.002249                     0
# 0786615206                     0              0.006382                     0
# 1480360295              0.007739              0.002601                     0
# 1928571018                 0.002              0.000598                     0
# 9792372326                     0                     0                     0
#
#             A0279100VZXR9A2495P4  A0600727NK5MAF66IOY5  A0727497OR0PPNFLFPDV  \
# 0739079891                     0                     0                     0
# 0786615206                     0                     0                     0
# 1480360295                     0                     0                     0
# 1928571018                     0                     0                     0
# 9792372326                     0                     0                     0
#
#             A07936821FOVJO6NP4Q8  A0833006NJW9KRF77ZFY  A0955928C2RRWOWZN7UC  \
# 0739079891              0.005686                     0                     0
# 0786615206                     0                     0                     0
# 1480360295              0.003764              0.027382               0.00357
# 1928571018              0.000778                     0                     0
# 9792372326                     0                     0                     0
#
#             A10044ECXDUVKS  ...  AZYCGMFCK9AIM  AZYJTD9J82V5I  AZYP4FQ2L2C4O  \
# 0739079891        0.002617  ...       0.012907              0              0
# 0786615206        0.001126  ...              0              0              0
# 1480360295        0.003489  ...       0.020344       0.001097              0
# 1928571018        0.000233  ...              0              0              0
# 9792372326        0.001631  ...              0       0.022063              0
#
#             AZZ3WYDJ0XNZW  AZZCLFV6V8693  AZZM5MUOG0LRK  AZZT9G4MJFCHD  \
# 0739079891        0.00569       0.005153              0              0
# 0786615206              0              0              0              0
# 1480360295       0.001751              0              0       0.000882
# 1928571018       0.000692       0.007247              0              0
# 9792372326       0.000986              0              0       0.002676
#
#             AZZX23UGJGKTT  AZZZ3LGTCGUZF  AZZZG8PGB1FS0
# 0739079891              0              0              0
# 0786615206              0              0              0
# 1480360295              0              0       0.019288
# 1928571018              0              0       0.001216
# 9792372326       0.030343       0.015025       0.008067
#
# [5 rows x 27530 columns]

# %% [markdown]
# Sanity Check

# %%
P.shape
# Out:
# (10620, 27530)

# %%
# P_dense = P.sparse.to_dense() 

# ratings_counts = (P_dense == -1).sum(axis=0)
# ratings_counts_summary = ratings_counts.sort_values(ascending=False).reset_index() 
# ratings_counts_summary.columns = ['User', 'Number of actual ratings']
# ratings_counts_summary

# %%
# del P_dense

# %% [markdown]
# #### 1.2.2.6. Recommendations lookup

# %% [markdown]
# Top-five recommended products for each user.

# %%
os.listdir(lookups_dir)
# Out:
# ['item_similarity_matrix.npz',
#  'lookups.zip',
#  'prediction_matrix.npz',
#  'product_index.npy',
#  'top5_recs.json',
#  'user_index.npy',
#  'user_similarity_matrix.npz',
#  'utility_matrix.npz']

# %%
import json 

recs_path = os.path.join(lookups_dir, "top5_recs.json") 
with open(recs_path, 'r') as f: 
    recs = json.load(f)

# %%
print(len(recs))
# Out:
# 27530

# %% [markdown]
# # 2. Info Retrieval

# %% [markdown]
# Fields relevant to prompting

# %%
relevant_review_keys = [
    'overall',
    'reviewText',
    'summary',
    'vote',
    'verified'  # still don't know what this means! but it seems important! 
] 
relevant_product_keys = [
    'asin', # not useful to the LLM but useful to keep track of
    'title', 
    'brand', 
    'price', 
    'category', 
    'description', 
    'feature'
    ]

# %%
# helper to rank reviews by similarity score 
def rank_reviews(reviews, similarity_vector): 
    # sort by similarity 
    sorted_keys = sorted(
        reviews,
        key=lambda x: similarity_vector[x],
        reverse=True 
        )
    # replace IDs with ranks 
    ranked_reviews = {
        rank + 1: reviews[key] for rank, key in enumerate(sorted_keys)
    }
    return ranked_reviews

# %%
# Helper Function to collect reviews by similarity measure
def collect_reviews(user_id, product_id, similarity='user', utility_matrix=U, item_matrix=I, user_matrix=S, graph=G, num_reviews=1): 
    
    if similarity == 'user': # looking for similar users to user_id who have rated product_id
        relevant_nodes = utility_matrix.loc[product_id][utility_matrix.loc[product_id] > 0].index.tolist()
        # print(f"Users who have rated {product_id}: {relevant_nodes}")  # Debugging statement 
        similarity_vector = user_matrix.loc[relevant_nodes, user_id] 
        similar_nodes = similarity_vector.sort_values(ascending=False).index.tolist()
        # print(f"Users who have rated {product_id} most similar to {user_id}: {similar_nodes}")  # Debugging statement
        target_node = product_id # we'll be looking for the reviews of product_id from the users in similar_nodes

    elif similarity == 'item':  # looking for similar products to product_id rated by user_id
        relevant_nodes = utility_matrix.loc[:, user_id].gt(0).index.tolist()
            # print(f"Products rated by {user_id}: {relevant_nodes}") # Debugging statement 
        similarity_vector = item_matrix.loc[relevant_nodes, product_id]
        similar_nodes = similarity_vector.sort_values(ascending=False).index.tolist() 
        # print(f"Products rated by {user_id} most similar to {product_id}: {similar_nodes}")   # Debugging statement
        target_node = user_id # we'll be looking for reviews of similar_nodes (items) from the user_id
    else: 
        raise ValueError("nodetype parameter must be 'user' (default) or 'item'")
    
    done = False
    rating_to_beat = 0 
    reviews = {}

    for s in similar_nodes: 

        if done: 
            return reviews 
        # if reviews contains the number of reviews needed, check whether they're all five star ratings 
        elif len(reviews) == num_reviews: 
            num_good_reviews = 0 
            for r in reviews: 
                if num_good_reviews == num_reviews: 
                    done = True 
                    break
                if reviews[r]['overall'] != 5: 
                    rating_to_beat = reviews[r]['overall']
                    break 
                elif reviews[r]['overall'] == 5:
                    num_good_reviews += 1 
                else:  # if no overall rating, remove this review 
                    del reviews[r] 
        
        if not graph.has_node(s): 
            print(f"Node {s} not in graph") 
            continue 
        # Now we want to find 
        # collect the edge set of node s 
        ## if s is user node, we want the out set 
        ## if s is an item node, we want the in set
        edges = (
            graph.out_edges(s, data=True) 
            if similarity == 'user'  # for user similarity we want out edges
            else graph.in_edges(s, data=True) # and in edges for item similarity
        )
        # iterate through source, target and edge in the edge set of s
        # if similarity is USER, the edge set is the out set of similar users and the target node is product_id
        ## which means the product_id (target_node) is v 

        # conversely, if similarity is ITEM, the edge set is the in set of similar items 
        ## and the target_node is the user_id
        ## which means the the user_id is u
        for u, v, data in edges: 
            if similarity == 'user': 
                connected_node = v 
                key = u
            else: 
                connected_node = u 
                key = v 
            if connected_node != target_node: 
                continue 
            if 'reviewText' not in data: 
                continue 
            if data.get('overall') > rating_to_beat: 
                review_info = {k:v for k, v in data.items() if k in relevant_review_keys}
                # key reviews with IDs -- we'll use later to rank 
                reviews[key] = review_info

                if len(reviews) > num_reviews: 
                    sorted_keys = sorted(reviews, key=lambda x: reviews[x]['overall']) 
                    top_keys = sorted_keys[1:] 
                    reviews = {k: reviews[k] for k in top_keys}
    
    # sort reviews by similarity and rank them 
    ranked_reviews = rank_reviews(reviews, similarity_vector) 

    return ranked_reviews

# %% [markdown]
# Helper function to find most helpful review of product (regardless of user similarity)

# %%
def find_most_helpful_review(product_id, num_reviews): 
    """
    Find the most helpful review (by votes) for this product.
    """
    # collect the edge set of product_id 
    in_edges = G.in_edges(product_id, data=True)

    for rating in range(5, 0, -1): 
        most_votes = -1 
        helpful_reviews = [] 

        for _, _, review in in_edges: 
            # find most helpful five star review 
            if review.get('overall') == rating:
                votes = review.get('votes', 0) 
                if votes > most_votes: 
                    most_votes = votes
                    helpful_reviews.append({k:v for k, v in review.items() if k in relevant_review_keys})
        
        if len(helpful_reviews) == num_reviews:
            # rank reviews by number of votes 
            reviews_sorted = sorted(helpful_reviews, key=lambda x: x.get('votes'), reverse=True)
            # format as dict
            helpful_reviews = {idx+1: review for idx, review in enumerate(reviews_sorted)}
            
            return helpful_reviews
        
    return None

# %% [markdown]
# Below is the main function for collecting the prompting info.

# %%
user_ids = U.columns.tolist() 
print(user_ids[:10])
# Out:
# ['A0072193KFP6LUHKEXLT', 'A0096681Y127OL1H8W3U', 'A0103849GBVWICKXD4T6', 'A0279100VZXR9A2495P4', 'A0600727NK5MAF66IOY5', 'A0727497OR0PPNFLFPDV', 'A07936821FOVJO6NP4Q8', 'A0833006NJW9KRF77ZFY', 'A0955928C2RRWOWZN7UC', 'A10044ECXDUVKS']

# %%
for node, data in G.nodes(data=True): 
    if data['bipartite'] == 'user': 
        print(node, data) 
        break
# Out:
# A3FO5AKVTFRCRJ {'bipartite': 'user', 'reviewerName': 'francisco'}

# %%
def find_prompt_info(user_id, graph=G, num_product_reviews=1, num_user_reviews=1, num_helpful_reviews=1, utility_matrix=U, user_similarity_matrix=S, item_similarity_matrix=I, recommendations=recs): 
    
    recommended_product_id = recommendations[user_id][0] 
    product_reviews = collect_reviews(user_id, recommended_product_id, similarity='user', num_reviews=num_user_reviews) # review of product by similar user 
    item_reviews = collect_reviews(user_id, recommended_product_id, similarity='item', num_reviews=num_product_reviews)  # reviews by user of similar products 
    most_helpful_review = find_most_helpful_review(recommended_product_id, num_reviews=num_helpful_reviews) 
    
    product_info = {
        k: v for k, v in G.nodes[recommended_product_id].items() if k in relevant_product_keys
    }
    # structure info in consistent format 
    info = {
        'Product': product_info, 
        'Reviews by similar users': product_reviews, 
        'Helpful review of product': most_helpful_review,
        'Reviews of similar products by user': item_reviews 
    }
    
    return recommended_product_id, info

# %% [markdown]
# # 3. Prompting

# %% [markdown]
# Initial prompt to explain task

# %%
task_prompt = """
### TASK DESCRIPTION: 
Your task is to generate short recommendation justifications Amazon customers based on information that will be provided to you following this TASK DESCRIPTION.
The products are musical instruments. 
The information you will be given is structured in JSON format. 
The structure is as follows:
{
    Product: {<key-value pairs providing information on the recommended product>},
    Reviews by similar users: {
            <Ranked similarity with user, with 1 being the highest rank>: <review data as key value pairs>{
            <overall>: <rating this user gave to the product>, 
            <verified>: <if True, this review is known to derive from a trusted source>, 
            <reviewText>: <the text of the review itself>, 
            <summary>: <a brief summary of the review>
            },
    Reviews of similar product by this customer: {<same structure as above. These reviews are of the products most similar to the recommended product, and are written by the recomendee user.>}, 
    Helpful review of the product: {<same structure as above. This review of the product was voted most helpful by other users.>},
}
Your task is to synthesize this information into a justification of why the customer may like this product. 
The length of your justification can vary depending on the amount of information you have to go on, but should not exceed a paragraph. 
You should avoid repeating yourself. 
You can include technical jargon related to the products, but should avoid other kinds of technical jargon. For example, you should not refer to "users" and "products" but prefer more approachable terms.
The next part of the prompt will contain the structured data:
------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
"""

# %% [markdown]
# ## 3.1. generate() function

# %% [markdown]
# <b> This is the function you'll have to change for different APIs. Currently configured for Google AI studio. </b>

# %%
import base64
from google import genai 
from google.genai import types
from dotenv import load_dotenv 

env_path = os.path.join(project_dir, ".env") 
load_dotenv(env_path) 

def generate(info, response_type="text/plain", model="gemini-2.5-flash-preview-04-17", api_key="GOOGLE_API_KEY"):

    client = genai.Client(
        api_key=os.environ.get(api_key)
    ) 
    # append current prompt to chat_history
    contents = [
        types.Content(
            role='user',
            parts=[
                types.Part.from_text(text=task_prompt),
                types.Part.from_text(text=info)
            ]
        )
    ]
    # contents of API call is the whole chat_history
    generate_content_config = types.GenerateContentConfig(
        response_mime_type=response_type,
    )
    full_response_text = ""
    try:
        for chunk in client.models.generate_content_stream(
            model=model, 
            contents=contents,
            config=generate_content_config,
        ):
            full_response_text += chunk.text
            print(chunk.text, end="") 
            print()
    except Exception as e: 
        print(f"\nAn error occurred during content generation: {e}") 
        return _, e
    
    return model, full_response_text

# %% [markdown]
# # Main Function

# %% [markdown]
# Global data storage

# %%
rows = []

# %%
import time

def update(data, field, value): 
    if field in data: 
        data[field].append(value)
    else: 
        data[field] = [value]

def LLM_attribute(users, graph=G, sleep=0, print_out=True, num_product_reviews=1, num_user_reviews=1, num_helpful_reviews=1, **kwargs): 
    """
    Pass a list of user IDs to this function. 
    The function will attribute the graph with the model_name+number_of_examples and the recommendation justification. 
    It will return a dataframe to allow easier inspection of performance. 
    Adjust the sleep parameter to avoid rate limits. 
    num_product_reviews: "find this many reviews of the recommended product from the most similar users to user_id"
    num_user_reviews:  "find this many reviews from the user_id of the most similar products to the recommended one"
    num_helpful_reviews:  "find this many reviews of the recommended product which are generally helpful and positive (have highest number of votes)"
    """

    if isinstance(users, str): 
        users = [users]
    # call find_prompt_info to collect relevant data 
    for user in users:

        data = {} 
        data['user'] = user

        product_id, recommendation_info = find_prompt_info(user, num_product_reviews=num_product_reviews, num_user_reviews=num_user_reviews, num_helpful_reviews=num_helpful_reviews) 
        if print_out: 
            print("*" * 50, "\n") 
            print("Raw Info:\n") 
            print(recommendation_info) 
            print("*" * 50) 

        product = recommendation_info['Product'].get('title', None)
        if product is None: 
            product = product_id 
        data['Product'] = product 

        # convert to text for LLM 
        info_text = json.dumps(recommendation_info, indent=2) 

        # call generate to return the recommendation tip  
        print("\n Recommendation Justification:\n")

        model, justification = generate(info_text) 
        
        if 'error' in justification: 
            print("Error encountered, breaking loop early.") 
            return data
        
        data['Model'] = model
        data['Num Product Reviews'] = num_product_reviews
        data['Num User Reviews'] = num_user_reviews
        data['Num Helpful Reviews'] = num_helpful_reviews
        data['Justification'] = justification
        
        # format the attribute name as model + n-shots
        n_shots = num_product_reviews + num_user_reviews + 1 
        attr_key = f"{model} -- {n_shots}-shot prompting"

        # find the Product-Recommended->User edge 
        for u, v, d in G.in_edges(user, data=True): 
            if u != product_id:
                continue 
            else: 
                d[attr_key] = justification
                print(f"{u}-Recommended->{v} edge updated with {model}: {justification}")
                break
        
        rows.append(data)

        time.sleep(sleep) 
    
    return "Justifications generated for all users"

# %% [markdown]
# ## 3.1. Gemini

# %% [markdown]
# Test on one reviewer

# %%
reviewers_by_degree = [x[0] for x in sorted_reviewers]
# Out:
# ['A2NYK9KWFMJV4Y',
#  'A396ELNTQDFYPO',
#  'A3YVD62FSVIUJ',
#  'ADH0O8UVJOT10',
#  'A2SUG35F6A6S3C',
#  'AZV2U6GU5QA6C',
#  'A1SD1C8XK3Z3V1',
#  'A15TYOEWBQYF0X',
#  'A1FOXJ8TMYVKRK',
#  'ALHC64J88LVWO',
#  'A1MVH1WLYDHZ49',
#  'AJK15Q9JOEHRH',
#  'A1GM01HSKCW77K',
#  'A2U53XJZLPQWX2',
#  'A1XEX009ZR6WXG',
#  'A20JJ8634DG3FS',
#  'A3G9836LYVXE7A',
#  'A1PNV7C43HXKDI',
#  'A1MHPGANXXGLC8',
#  'A1T0CLFXA77001',
#  'A2VDKEI5V937X4',
#  'A1RPTVW5VEOSI',
#  'A273KCH4QQ8VR0',
#  'A1ESUYMIG3TZT0',
#  'A1VPJT3BHZ9UAS',
#  'A1DVUFG2QSJ6IK',
#  'AKYDGCKCY7H9F',
#  'A3EWG5C5KW5W9C',
#  'A3M1PLEYNDEYO8',
#  'A1A6VRGDEUFSPQ',
#  'A1OGTL9EBDTK3N',
#  'A3AOPVQ7EZHTWA',
#  'A182VFGL9YR6SZ',
#  'A3DILTDN3BLZP0',
#  'A3C1GOWBI1PCB6',
#  'A1F1C6B24D97CW',
#  'A3H4S6YO9VNGDZ',
#  'A129WUT5OMBKG',
#  'A3J6QCWLBVP3HX',
#  'A2EZWZ8MBEDOLN',
#  'AKHWZ3S1UVZAO',
#  'A2I7LG2P04A2IB',
#  'A1EVEQAR05SY7L',
#  'A1XSJ80M39HD7G',
#  'A38TYXTNN72TK8',
#  'A22Z554ZQ8NFPC',
#  'A2T4ET67G37VE6',
#  'A1DXBEKAZ0K6FI',
#  'AWY308ST6QBNK',
#  'A1GMWTGXW682GB',
#  'A2EDYSY4M8TESS',
#  'A2MZ8IKTPCMKPT',
#  'A134J0S1HWE4F7',
#  'A15UON6342H4YU',
#  'AFOH0F3VHSTIU',
#  'AXWEQHTXQWR7Q',
#  'AO21QAFMIK124',
#  'A28JEUI94PMR4W',
#  'A3SDJ70H00OQCJ',
#  'AZAYBFPLEDFL7',
#  'A10E3QH2FQUBLF',
#  'A3ECCP0PDT0SNI',
#  'A1LJXZC1RFW07C',
#  'AJCHGS1GND4OA',
#  'A2MR43RDPZX3J',
#  'A1YP96MT6W9FTB',
#  'A3LD23Z6C5LI40',
#  'A1YR3RVSBZK8CW',
#  'AKLDKUON6YY0X',
#  'A1OV2BH2S11KBA',
#  'ATPP3IWN4S9PW',
#  'AILKGRMLEMGXC',
#  'A1H2D403IZ5E6K',
#  'A3IKOEE8Z3T6BH',
#  'A26SN2CVQM4FKM',
#  'A3EQNAVEUFQIZT',
#  'A1IEUWQJOFCHNH',
#  'ATZCRPINM5F87',
#  'A74IPVDZEHJT8',
#  'A1NIKN47BZXWHV',
#  'A31GXUDTE66QK4',
#  'A3QVA0HAJUXIPM',
#  'A284WNP6L4M0BP',
#  'A1PV1O0WCRW7OQ',
#  'A2LNK3F5LWNO8V',
#  'A3U4HWDM8ZCP7X',
#  'AOZBVGFIUY44X',
#  'A2F4T30CPV56IY',
#  'AZBUUKQLYKUCL',
#  'A67OJZLHBBUQ9',
#  'A1J87SYB3JPQWH',
#  'A34O0KQV4QXWNQ',
#  'A1SXYKNFEGZMCG',
#  'A314F8HROMSXZF',
#  'AJOF2SMAYPBQT',
#  'A1YDQEVBW8WLS9',
#  'A1SK6R9XKJV8YM',
#  'A24EE20COX7OM9',
#  'A3OA4DV4L81N1D',
#  'A6FIAB28IS79',
#  'AJQX858JWAHDZ',
#  'AGYH5U11ZKPFB',
#  'A1Z7N2DXQF07XG',
#  'AZI67DUGQDCDW',
#  'A16FNRY0AK3MUL',
#  'A2JKCA8QF1NC5R',
#  'AZVME8JMPD3F4',
#  'A30J7WQV0ZNRXG',
#  'A1MA8SX2DYIPRQ',
#  'A1DM34L2CW44ZM',
#  'AR4QBG907EGYR',
#  'A2101DHHDMZ93X',
#  'A2053ZJUGCKUA5',
#  'ATJN91PH28F6T',
#  'A1A15ECLHM9BQY',
#  'A3IVULXGE2PB43',
#  'A2KFKEME4A9ATW',
#  'A17Y6FE1XWX9MG',
#  'A2LFYTX1544TZM',
#  'AV8MDYLHHTUOY',
#  'A2XP1F29W6TIZO',
#  'A395N4YTYU0UUF',
#  'AL8K7SWTLZ12X',
#  'AVFQ69R7AU8ZW',
#  'A3B453GANDJNOZ',
#  'A3CSSZ6U5J4YS5',
#  'A5RJ7TM82RH0I',
#  'A0096681Y127OL1H8W3U',
#  'A129UKDJUW5VSZ',
#  'A2FHTXLKY1XJDB',
#  'A2HMDN9HHJBVJT',
#  'A3S1LSTRW57BP9',
#  'A3G6P4SJ8SYH9F',
#  'A10044ECXDUVKS',
#  'A33YPBLQW8AQOQ',
#  'A2DT2C0KOUQ0GX',
#  'A1EB5UMOZR8J0W',
#  'AJBBU53A0X84I',
#  'A3IICSS30MRX9M',
#  'A3TBMAWIIHKHFN',
#  'A1RZ32JTYABQWI',
#  'A3EZFFPVS34AMO',
#  'A10APIDAZISWQF',
#  'A33NQYGEJU76Q8',
#  'A1WQNVR4H66YX9',
#  'A136IQFGB01KQB',
#  'A2D5I9S4FMZTIO',
#  'A1JDPFN44PHOL1',
#  'ADS0874E1ZZTL',
#  'A2D0CM6SAMN31R',
#  'A2OPSPL8LSSJPC',
#  'AR6CAR106LX2Y',
#  'A2J5CQFCB11VKJ',
#  'A8ANJNZAZQ6IQ',
#  'A3ALSCQ9851A8Q',
#  'A2MAL0M9EG4FJH',
#  'A1YJIWBQOKBXJQ',
#  'AQDUE9PHA7QRP',
#  'A11E51YAC4ZG0Q',
#  'A3QZQ6W5NS4E7V',
#  'A3OXHLG6DIBRW8',
#  'A32XC5P9YISTH2',
#  'A3F9ZR46O8LCDI',
#  'A1HQN6CNAO683Y',
#  'AS1ZVSX5FA84W',
#  'A1Z3E1A2XZ5BK5',
#  'A3KFZP45ZQT5ZD',
#  'A39P7FC5WIEE6J',
#  'A3RCJDG26PLNTZ',
#  'A2XKROL6XBFHT3',
#  'A35HTG0YUEKFGM',
#  'A2OXHJK2NV75ZR',
#  'AW5D9Y2AZAZUU',
#  'A3N0P5AAMP6XD2',
#  'AFS3FQR5JSDVJ',
#  'A3DMJLKEUNQDOX',
#  'A341MR306CXLM7',
#  'A1BC62X6HZJGZR',
#  'A2KK52IFW3AK6Q',
#  'ADRAB7F3AI7OL',
#  'A17198YCCO7GC4',
#  'A1365RYO0BLEMI',
#  'AZE83O4F1IJPR',
#  'A3G0EP7W1VPY2W',
#  'A2U9OJO2GLVEEC',
#  'A2WROWUBLQ9GZZ',
#  'A59G70843Q9AI',
#  'AXUJFOFQZNTN',
#  'A157T7ALB7BE89',
#  'A26M5O53PHZTKN',
#  'A7QMNRUXA4HTI',
#  'AP86M5T0VHBH1',
#  'ACKBEBTATVAJ2',
#  'A24ZWSOUJ0959N',
#  'A1MAQQXJZTMSKT',
#  'A1537HLRO240XP',
#  'A1CUY6J6145C93',
#  'A1IYW63ZV9E8YK',
#  'A1ZRMGNB5NZFQX',
#  'AJGIN15VFGXBG',
#  'A1CL807EOUPVP1',
#  'A1SMOG7XY23SIY',
#  'AEN6KDJ3AJDK6',
#  'A3BTH66WVCQAM9',
#  'A1MI9FDCNB3CMR',
#  'A3USVXMH3QNRLG',
#  'AAS4DS4Q88FLZ',
#  'A1MNCU4G0FKD46',
#  'A2VGUWQIMYX7SU',
#  'A185KIXEY9QZRQ',
#  'A31GQ2U36G30IG',
#  'A2VM3BM2HZ1PSN',
#  'A20IIR0422G3A5',
#  'A35A1KHOHENTPV',
#  'AYP7YOSLPC5NP',
#  'A9SINTLKCQK90',
#  'A3BDD4NKPRFP04',
#  'A2XXBZPQT5EXHV',
#  'A1C0O09LOLVI39',
#  'A2H7OE1TTLK3P4',
#  'A3RHPUZBOP4D47',
#  'A2U2U69S0ITFJ4',
#  'A2CHBPVZ3UIJ0Q',
#  'A2JC4OU1SA47G0',
#  'A2UZ219VYXN78J',
#  'A3UJRQF8Z39J3S',
#  'A2NUGDR0Y9CHTK',
#  'AJORX8PDEWL7W',
#  'A3RSLZMFS6KK6E',
#  'A27GPJSZDRQ1ZW',
#  'A1K1LQ2CDQLR3T',
#  'A1D098MTZUFS6J',
#  'A265SU6RW4ZAPY',
#  'AVOFQL8D5NLUO',
#  'A13G34EAZXEXE8',
#  'A2UDGB5BTYY51',
#  'A1B3CNORXB1USI',
#  'A48EICWVELGDS',
#  'A38UO326AF4NUN',
#  'A2E3D6W7MW0WX7',
#  'A121S4HE3PUFB9',
#  'A2ZKB8HUGY5GQO',
#  'A2NJIJTO9WIUSK',
#  'A325Q8LI2V97XV',
#  'AQIVKUVV9NJWQ',
#  'A2FFJCRIYMCVCZ',
#  'AKAVVQMXSAIGX',
#  'ASCOQL6HNN0OE',
#  'A7O84T8MC6IV0',
#  'A3EQ8A6DQ7GBAS',
#  'A215GPS2IFRI7G',
#  'A22XP8CF9U631W',
#  'A1ZXTQA6K1YOJ0',
#  'A3PZYKYBGM8K7G',
#  'A1IU7S4HCK1XK0',
#  'AENULRBQ2IE5I',
#  'ANKVW8VF8OX52',
#  'A1EUO0BU72JR7T',
#  'AXEVGGJ6GBYHX',
#  'A3D42ZX96FA6EW',
#  'A17KQY4T4RZ7RT',
#  'A29LUOSQYME7XE',
#  'A2RUGSBYLJ261S',
#  'A25ZBYVW8ZINLM',
#  'A3FQ9WYUHG9CD',
#  'AR4NURQ42A0Q5',
#  'A2YUDQKESBIEEU',
#  'AZJPNK73JF3XP',
#  'A17F1YM8GEOPZB',
#  'AY1PBW0ZWIE6V',
#  'A294N8YW6BUGHO',
#  'A2VAD79S4A06DD',
#  'A3H48AH54MAC59',
#  'A3FV6ARXFEAX5Z',
#  'A2HNEY2CVEAT84',
#  'A3TTVWLIHLQPUW',
#  'AL1PNYDIILV4D',
#  'A3EATLL9FW7DJL',
#  'A1XN2ORFU4W0SY',
#  'A1K3LPKZN4OZ66',
#  'A2TKMA52AMCB31',
#  'A2VWNZNFV8QCP0',
#  'A38HY9YF5PI15G',
#  'A2C00NNG1ZQQG2',
#  'A3MY4TZI3R7A1L',
#  'A1FWF4TNYKN36K',
#  'A23AKO4BZLZ8DE',
#  'A39GCOOEXQ6QQD',
#  'AC14O8CFLBX26',
#  'AWIG50VOI5VUV',
#  'A18Z2ZMIJDUJPR',
#  'A5SF5XIV42MW5',
#  'AEUT4MUMNT2S8',
#  'A15N3ETU8WWAUB',
#  'ALQSLK948GGFY',
#  'A3DM4MOJKIPMUM',
#  'A2QJRGXUJRLLSU',
#  'A222KCMJ1XOGXJ',
#  'A37IVIAKXV6L4C',
#  'A3VQUWY0ZRLFR0',
#  'A2GVCOYEIGUEQY',
#  'AEYKPDYE0CCG7',
#  'A2FD5LWT2BXO94',
#  'A3CAQMCVKGMCY',
#  'A1DE9TVBOVWXP1',
#  'A27EWIL4YBWTA0',
#  'A8L6Z9U1TCP06',
#  'AUNPH17AQRJKU',
#  'A2N97VNHT1W928',
#  'A1RDGOGEHTQNO2',
#  'AG8AHNDVN9KQL',
#  'A2MEN74OQVUP2B',
#  'A2VKH0FDSTMK2A',
#  'A2ELXV8CZPFVO8',
#  'A2P0Y85C896QIB',
#  'A1TO7PNJ6W7OB4',
#  'A1TWEBKVZDD2JJ',
#  'A1MZH3AW94SNWV',
#  'A344EK7LU4Z77Q',
#  'A2SRCVYVHA6G19',
#  'AF79PUU0A2616',
#  'ALV33FTOC032I',
#  'A31UEB0NDFEM8M',
#  'A3775OP5VTX5ON',
#  'AJFQYHQVBJN5M',
#  'A1EIJ7DDZM2TPJ',
#  'A3Q473P3VQV2IZ',
#  'A2DMN4O3N9Z3H7',
#  'AGYOOL07RRWG6',
#  'A1V3N0LF1QGG0X',
#  'A3FUKVX3B48315',
#  'A205483DF7XVDE',
#  'A3KLA39CHK9JHV',
#  'A1QUNDM9NDNQ3I',
#  'A3RUXTIR7OEZVG',
#  'AG3PVU7DCXZTK',
#  'A2CMN999R94YAR',
#  'A3V296F5XF0YHA',
#  'A3O583ZUFQ3QGB',
#  'A3IGQ7TY3NHKFG',
#  'A1WJBJUQ24G8BU',
#  'A1UB6Z3RO4TQYW',
#  'A1XI56UNZDBW2M',
#  'A2A70C4O82ZYEG',
#  'A2FVE1P5YERMRD',
#  'A2Z7S8B5U4PAKJ',
#  'AHE4RU04NVDHR',
#  'A17SLR18TUMULM',
#  'A3HCK3UXD6WS4G',
#  'A14Z9LAETO21KL',
#  'A680RUE1FDO8B',
#  'A2RIZEL6RI8RNJ',
#  'A3L1VJMHFWONCB',
#  'A37A41GWQFMK3D',
#  'A2VAB2CTPQ2TJ',
#  'A34LQ791ACZ0JC',
#  'AL3G7RTXMGLDQ',
#  'A2Y8JW5NSY95OL',
#  'A2D0KNY2GLTZZ4',
#  'A1PD9ZCHDJOGBP',
#  'A3SAZLWQ86H32',
#  'A2M8T1A4O0GS72',
#  'A21GCOGHDQNHQS',
#  'A3PGQWCSJPCYDH',
#  'A2RVY2GDMZHH4',
#  'A1QIT9HX39HLI0',
#  'A60K3A8535404',
#  'A24JH8BXAUCFU9',
#  'A386341MZWM9E4',
#  'A1L45HKT7H5SPJ',
#  'A12DBY0RDJMO1J',
#  'A3O4ZM66RUOGS7',
#  'A2VS9AKSIA487A',
#  'A3DNZH1BLTMD2C',
#  'A2GHYL357KN5D7',
#  'AYVW3O6W8S5S4',
#  'AZVSR85CD9XG5',
#  'A1GJA4JLBRV1NN',
#  'A2MCBX34ALVCIW',
#  'A3M47Q7TVTYMQ6',
#  'AQR6FI9TD1221',
#  'A26JHKA8SNXV6P',
#  'A1EL2FMHLNPRT4',
#  'A1GBK442FMSGRN',
#  'A3AAUG2Z6BD186',
#  'A2F92AOWTIUIB',
#  'ART22XD9HEZXF',
#  'A1VK8LTKHZELGP',
#  'A29F4T1VXNA9AD',
#  'A3MI52IXOKD1XE',
#  'A2T6O9LRFP2POU',
#  'A2K3M2TEV17EJK',
#  'AT01FH4U3GP0O',
#  'A3SXFP684N95P',
#  'A98T7BK2LD4OY',
#  'A3T7QL2H8SJRZJ',
#  'A2MKG8P7L2PPPB',
#  'A18MMME07XZLYO',
#  'A21Q29J3ZWPDNP',
#  'A22EW8G85ZBHLB',
#  'A35KYGOA3Y717Q',
#  'A3ROFDX81WN3VN',
#  'A2QLAZJQ85TCPT',
#  'A39GYDIYGO8CP0',
#  'A3TH7JFRIOPMQ4',
#  'A2MIP3AQVSF2SS',
#  'AGHMAMHIW4CDQ',
#  'A214Z8EQMEJPWJ',
#  'A20TFY5J3WNJU2',
#  'A1RSRUQVKB5EBO',
#  'A23HJIRA5PIMG0',
#  'A2ER327BNABIWC',
#  'A2158NV89I72OP',
#  'A23T4EXRCVW8QA',
#  'A1BUS5XH0Y2VTQ',
#  'A3J1M5WTA3ST77',
#  'ALVO1A5UB8DG0',
#  'A16I4EAK43DI7N',
#  'A2J5JJ34V1IET2',
#  'A1LDMAZ3C8Q907',
#  'A2FRF1SHFWFP3I',
#  'A3E57Q7V46X6X2',
#  'A14DZY6S9MLJB0',
#  'AYYCQUNL175D1',
#  'A2GCJMPR4E9X04',
#  'A1SZKN6T4J9KMH',
#  'A3HNKTVQO3B037',
#  'A2Z6AF3QDPT29V',
#  'A26TJTN6GHF4GP',
#  'A1ZRXGT8QJXGET',
#  'A2Y7BSQG9V3LNG',
#  'ALH5BPA9YOHFP',
#  'AKPVT396SPLII',
#  'A36KP6KBIR04A6',
#  'A2E71UQ5DHQXOX',
#  'A1VHYBN1NV73LZ',
#  'A2PLMQBUKG06L9',
#  'A18ZYBZLR66IWK',
#  'AWP0JM6XEVGIE',
#  'A26RNTHH6P38YJ',
#  'A32L1WHBU3BA7H',
#  'A3IG2AUS1PVNH2',
#  'A1N06X05VZWO5Y',
#  'A2VH0UT5EQFB6P',
#  'A1JJ61UV88EAP5',
#  'A342SD2VYIW6NR',
#  'AQ0DQFCCQHVP2',
#  'A2XW8R727HVU79',
#  'A3PGQF019PLVAZ',
#  'A3D0I5TLNFFXWZ',
#  'A3RZQVOGIYWCWS',
#  'A18C03TA8N26L4',
#  'A6LAHM3TAEFYQ',
#  'A2D0F87RY5YMHN',
#  'A3PWHUQF5LDFX5',
#  'ADX51B11I24GZ',
#  'A36F0NJX0VCRQA',
#  'A3G0QV38IJ1CYA',
#  'AS1E6X67ZJ7WQ',
#  'A1GFG7INFTBCIB',
#  'A2QRBBEK41CAKO',
#  'A3LSEIG2PIJYBL',
#  'A12DQZKRKTNF5E',
#  'A2NFZXXT0PWKO1',
#  'A3PB1FI3R9V7PY',
#  'A22HLJGJ6LM1QI',
#  'AG2F6294SBK3H',
#  'A1S7QABO64Z554',
#  'A2T639IINN6BTG',
#  'A1XNCV67JBJVF7',
#  'A3SMT15X2QVUR8',
#  'A3IDC5FP52KJWJ',
#  'A3Q7YYRYDXL1GD',
#  'A35GT39YO268D',
#  'A828MKX7XSRVF',
#  'A6U75KGQPG7BW',
#  'A2C4L5VVJ9STNH',
#  'APFIE26BTMWSN',
#  'AMH3MVGRC2YG',
#  'A1EAK9W2Z6KIKW',
#  'A2ZSD8WW1YWCD5',
#  'A1WLH57DO9JW6O',
#  'A3AE0KPM3L0RST',
#  'A1BKYC6UND5ACW',
#  'A2TUZFW30D6HUM',
#  'A1G6JLFGCAB38D',
#  'A3RJMFAS2MC957',
#  'A2A7XM5QDYDSUG',
#  'A29SISUDHFRI1N',
#  'A3GMADUPDANSDR',
#  'A1MU6PI3YDK8H0',
#  'A14JBDSWKPKTZA',
#  'A70UMKW9NULZ',
#  'A3TFVT2WOAOHCQ',
#  'A3U3YXX4P1X59C',
#  'A12D965GUIR3HE',
#  'A3KF2K1ZMAZSX4',
#  'A1MT6X1LTGMZKN',
#  'A1S0HTDO0P4N5V',
#  'A24UGH7K3XMZJD',
#  'A3LNBL3ZK0DR3C',
#  'A1293WNF15FORT',
#  'A3MI2BBKDN8EFR',
#  'A26T5GC7S7FGBJ',
#  'A35D9ODUCAMF5G',
#  'A1358WVA02SPNC',
#  'A2CHQH95XQUY4E',
#  'A1UUCIQB2FJIHN',
#  'AOINAOO0NQRGN',
#  'A5SRLPK9A3LG',
#  'A2X1UW7ITXKMY2',
#  'A1TNJ5721Q0928',
#  'A1TVFEIAK9EMID',
#  'A20L6NV2BE7UDU',
#  'A2A9OWDFOTQZP3',
#  'A38DCVO9SZHW68',
#  'ANSVB7OYSXZSL',
#  'A34488HCARTJ82',
#  'A3953QM5QH4B88',
#  'A1ZKTQ0O7U3GT',
#  'A1NAA1R38JSNHV',
#  'A3V6MF8K5PULOQ',
#  'A31B0LYT2C92SN',
#  'AJM1PHPJ4UWRE',
#  'A36OAWDJNRRV8U',
#  'AONGA3BHTK0EG',
#  'A2BKP2PL38TY1F',
#  'A29LQQAZHAGGU0',
#  'A2CMX45JPSCTUJ',
#  'A3HR0WYF78HU7X',
#  'A151AZ87B36FWH',
#  'A2EO7QLWKD287K',
#  'ABBE2DL4IFLM5',
#  'A1V49DJOK25J0R',
#  'A3HJF8AM51U0TP',
#  'A34PLMOCZNSYAN',
#  'A1WOEXR8EW2HIP',
#  'A2VY4F62JE9HCJ',
#  'A23824RXPHOIRL',
#  'A2EGY9MBMWGBL7',
#  'A2GLR2Q3M1PC7P',
#  'A33Z1FXHNTWI9V',
#  'A25WJCAP606YMP',
#  'A1BQKMP3478PAC',
#  'AGA6B9FHJ6HY0',
#  'AR64CEBJWBICU',
#  'A2IFKMKKXV8AVU',
#  'A1P1E3DFR2RPAZ',
#  'A3ET07GFHXEQRA',
#  'A2PVAOS0G22ERX',
#  'A25ORF72RXGY3F',
#  'A2A039TZMZHH9Y',
#  'AH6BWZKE4FQ01',
#  'A10P1UB769E59J',
#  'A3BCK6EDQ76GZK',
#  'A1DOKWAFHIGE8C',
#  'A2TCEVBUWSALVG',
#  'A345PWU4ST401I',
#  'A19AXCVXAM7NM2',
#  'A3KX8SVSUCSHKU',
#  'ABZYVME9NYCQG',
#  'A1QFZBIU58C86Q',
#  'A1ARYK0MUG0DTR',
#  'AXOV3QCTN782N',
#  'A3NFYX16H2N4M8',
#  'A2NBG5RD1D2X7O',
#  'AR0Z2AVWQ8F1Q',
#  'A3RHT4KI3H5TVH',
#  'A3HN5DKJQDB0VV',
#  'A2F2L5F9OWWVY6',
#  'A1WU3RDNM8Y8Q9',
#  'A1ARIIDS0IPYLC',
#  'A3KY3GD64EK62A',
#  'A23NCKH61PJ22C',
#  'A32FF7JMTOGEB1',
#  'A1YCDZ4K4G0CN3',
#  'A3JDYGP8T4145S',
#  'A1MJZ6MQ9Q5S0Q',
#  'ALAY8GVFBUQ9L',
#  'A3I8K0WNU0X04Q',
#  'A1NOELD0FUS78X',
#  'A2P83FWHR36WN1',
#  'A35Q0RBM3YNQNF',
#  'A2DD4Z5UNLDVJT',
#  'A3SUC2DJYHUU9Y',
#  'A1V7G6OGGW7AGA',
#  'A1HW9DAJBYXGDV',
#  'A1H76HP3D76GZQ',
#  'A1MM26M78136ZP',
#  'A2J4UAF6RW13WK',
#  'A2XPLOKZQAQ94D',
#  'A2BGZ52M908MJY',
#  'AJAIO7P0JG2IJ',
#  'A1FVLFHC6WMLD6',
#  'A3I49HMI4LV6HU',
#  'A257REAK0Z8II5',
#  'A2MK5QBEWG4Z0B',
#  'AH2HPZMJ52MFB',
#  'A2AIFWGX6KSUHE',
#  'A19R0WEVVAVTLN',
#  'A39L9JAGHNIJEL',
#  'A1AN5JP7G4KFOQ',
#  'A205CVP06GX7Y0',
#  'A2Y2U697SS98E1',
#  'A22OB4MV6UJE0Q',
#  'A2NE6G355A55RE',
#  'A33PUQETQAM8XT',
#  'A8I8WH1MS2455',
#  'A2SBZZ1HSR7WSP',
#  'A2EGE911HYQWJH',
#  'AF1I90O6U8VCQ',
#  'A2HTCOI1ENAEUK',
#  'A2EBN8LPMN45UA',
#  'A2DKW2PEHRTT6N',
#  'A5Q8HPPRY3ZLT',
#  'AGOMW95M7MIV',
#  'A2ZUHWM3EGEAAE',
#  'A1SMX5YG96L5IO',
#  'A3EAVE96K15COX',
#  'A25QPZOMZTFFV8',
#  'A2LDCAGY41TKNW',
#  'APVLFUAI3IDF7',
#  'A1U7PZZNRI5AV2',
#  'A8LC5CD5DEC6Q',
#  'A1L13HSZ8GGXU7',
#  'A10XQBLOU69ZAE',
#  'AFVB8SDUM2WCN',
#  'A3TZYKB4ZKZAI0',
#  'ADETB8KEATML7',
#  'A1T0W8JXB4USYB',
#  'A36YETCRHSOO26',
#  'A1LS2UXHG1BYRG',
#  'AGIFQISOUTQTG',
#  'A10ZZKL69LGS3W',
#  'A2WNPQVLW6H09O',
#  'AACARGGYZPQVN',
#  'AYJG6V3AQONGG',
#  'A20BHA430QDYV2',
#  'A172JIEF6MX2YG',
#  'A24JUT24W1K3CV',
#  'A2PDKKY9924V8A',
#  'ATJ67JCXK1TO8',
#  'A1BSHER7DCC9IZ',
#  'A2TTYZ3X5WOA8Y',
#  'AS7PHR0F1TU8J',
#  'AH4HBHRM707WA',
#  'A30J791OQS1LU',
#  'A18P5I03P4U8AI',
#  'A21VI6TKFRAQXA',
#  'A23MZM4TK3GF8E',
#  'AYLMCMFXM4PZ2',
#  'A1IETQQC4MRKE6',
#  'A1XDIC6OQKYJXW',
#  'A2BO055OCQH12P',
#  'A3AT69S9R8ZWGT',
#  'A12WYA15HUDTZS',
#  'A37A8FHCCXC1JI',
#  'A3CZU96XCN565F',
#  'A1GKEPHEDJY26U',
#  'A15LRHLNXP7JFI',
#  'AH4EE7JBRNPS4',
#  'A3EMQLSLCJ33N5',
#  'A22B2V1QL99Z85',
#  'A1OY65LIH53EHK',
#  'A3I23DPVLDXAB2',
#  'A3PII5YGK0TLH3',
#  'A3ADSZR7QAQ5U',
#  'A3GNWLMIMUTSCJ',
#  'A1F5HMIDLSR3EF',
#  'A4XWMOFB1HY04',
#  'AOFLZO8T1IF3B',
#  'A158WIQJCLENUM',
#  'AQ7BGREY7SUO2',
#  'ACW9QRY92GUY0',
#  'A34KC9EY3ZQ5T8',
#  'A8FAMHJNLHBJU',
#  'A3JY1DP21DLJRI',
#  'A2B5YWQ4B82BY7',
#  'A3LVOTYCDMDLTU',
#  'A3M283U263KNSF',
#  'A1QJPXDGJI5IQC',
#  'ADP33IFGFSL6',
#  'A1NH8T4CT2VFL',
#  'A1EWYZI4ZHU9XZ',
#  'A34LCHH9NG22ZG',
#  'A1WHGNU87BGJ2S',
#  'A17OA5A06LI2C1',
#  'A1BNV7GZCYO7NG',
#  'A2T8TWZAWLQWBV',
#  'A23D13HKTA95WX',
#  'A180V1LL4P8GRF',
#  'A137H7THVY77',
#  'A29TZ6OMFC2S8T',
#  'A1YYSOGNC6D68G',
#  'A2LSIGPM9FBVXZ',
#  'A3OCE03MZ2PC2J',
#  'A29B4PAIOL7HYG',
#  'A1JGH7L92J8TP4',
#  'A1YPXX9H1EQC3P',
#  'A25SVSZOMF6CHC',
#  'A3TIL1PC2ZE97B',
#  'A15LAJVR0RX15T',
#  'A2PD27UKAD3Q00',
#  'A1R53AIIG40UBJ',
#  'A1T9A8YD2FU9UF',
#  'AWHKACTSX0X33',
#  'A4HERYVWL1E8G',
#  'A16N6N1QUUIGAH',
#  'A2YGWCX3DQ6ER0',
#  'A9E9KTL53GIBN',
#  'A3D0PD45BHLXFX',
#  'A3S9FKS57WFLCU',
#  'ASWN54M6HH5OG',
#  'A1MQ29ZVEBWY3N',
#  'AXFNC11IE5NYW',
#  'A2SS31AD92R6VD',
#  'A3JYKP076RBZKX',
#  'AA5Y9QEATL533',
#  'A24AQ24CD6865K',
#  'A1YXMTTSZFR1QG',
#  'A22LLQ00V32YZJ',
#  'A1XSJVKDY75P7D',
#  'A3B8TCJW2JUUYX',
#  'A3GZ4FZE365SVJ',
#  'A3KDRLIBWILPMJ',
#  'A3TM9RWCTMIK42',
#  'A1HAHPVY5LDEC0',
#  'AKV1EJSHOPLP7',
#  'AIYGTPLDBNVDP',
#  'A11CXXMFJD9SGI',
#  'A1RY961AEI67NT',
#  'APTA3KSEUILVA',
#  'AIP5WPWPNOKOQ',
#  'A1JNV4K56GG94R',
#  'A757XFFO7TT4P',
#  'A3LMH7M7YGUW81',
#  'AMVC9WTXYKNJ1',
#  'AXIJQPZCJN6XY',
#  'A5FM3BY80U9EF',
#  'A1UMM894XSEO4F',
#  'AZ0LJNEP2VRD1',
#  'A3IUX92PY69MSL',
#  'A2NW1N71JQ1P2X',
#  'AMP0Z3DR4RCH7',
#  'A3F1GM7ZAZD1SW',
#  'A1LCPSH9KIPINR',
#  'A19BX5QN417AVV',
#  'A1DLTUNMANB6Y0',
#  'APEJ8EJCC8PQ8',
#  'A1VKC9AA9V7AUZ',
#  'A2M519V1URDFSP',
#  'A29KD0G3J0V3JR',
#  'A2EIV862QN1JYQ',
#  'A2CN9G73EE403R',
#  'AFAFD8L0SENRB',
#  'A1KPVRW3QEUOQZ',
#  'A2QEH1K92PBWMQ',
#  'APH7O58XJXKPT',
#  'AQCPTKTUQXXQQ',
#  'A8C9WGWHBRZ5E',
#  'A1IR4OHC8K0TSV',
#  'A1TUTA0UOBZQKH',
#  'A1EFL0W7WFO0UX',
#  'A3CSWB0L9ZLD94',
#  'A3VPJNX40SBP1M',
#  'A4O1N2T65H5U',
#  'AOMEH9W6LHC4S',
#  'A3VODQSXVMIAUV',
#  'A2JDPF17IADCOC',
#  'A1E89Q4ZJC2ED6',
#  'A15WZCSME5X74S',
#  'A2KWBJIS8TVJ2S',
#  'A1P56Z6DAWXI4W',
#  'ART43EESRGMNC',
#  'A2LE9QQY1WZ48O',
#  'A2AN8V5AM1XJ7P',
#  'A3CMSCWXZIVJQ1',
#  'A21NY4LQ940JO2',
#  'A3D4ZPNGZB8RSY',
#  'A2GQMRR2CCD78W',
#  'A3BEKIXEMSZ9PL',
#  'A3B7EYODVI8T70',
#  'A3621QMU492VV4',
#  'A1ZMV5QSAR8V2L',
#  'A34ZTK694FTCAE',
#  'A3F6705C4CSLBV',
#  'A13IKQCJKFAP5S',
#  'ACTENPA96XEMO',
#  'A43ZI5JO5FDER',
#  'A12752HRLFJZKW',
#  'A35PMER7ZH4Q0R',
#  'A37F75CD3U5ISK',
#  'A9GIGJUB98JNR',
#  'A19HYTAPU7POPV',
#  'AKSFZ4G1AXYFC',
#  'A3DF9X8J51MFDO',
#  'A3DNL4U0UPLYL9',
#  'A54S9CIUV5VNB',
#  'A17CU1D2CWXOHB',
#  'A2S696CI415O20',
#  'A35QR07ZW63T65',
#  'A2BH9EKXZ1RZXH',
#  'A2OSWBBI557NXZ',
#  'A2EZ80LJMEMJM9',
#  'A13T4T3QOSII3I',
#  'A781ITP3HE2N5',
#  'A2ZXDYXR8XU01Z',
#  'A26TTHD7OS25VF',
#  'A3V1A3C9DTLPME',
#  'A3SU1JZBMQ5ABZ',
#  'A2N4QZ92NBKJZZ',
#  'ACK2DE0T9AVW3',
#  'A2O8BAXJPDSV0M',
#  'A20KJ1P0NIVZHS',
#  'A1BW6SNULSNCTQ',
#  'A2ZGEV4CTSCTIZ',
#  'A33YZNZIRA3H97',
#  'AKDQ6O42VUK1U',
#  'AD3EX5UG7UZPB',
#  'A1UEX5M9XR3ZCO',
#  'A3QAILPOPQI3TC',
#  'A2AHD6WEBBT0Q6',
#  'A11UETVJSJJSUI',
#  'A2X2GEABQXRX7P',
#  'A1IL0PS2XJB4NS',
#  'AZ9YQCI92ZCP8',
#  'A3RDS0DJ5EJGA7',
#  'A2771TQ9KU1LYE',
#  'A1TSKKBNV38E8Y',
#  'AACGCOHLPRN4H',
#  'A36U2CRYR44VXS',
#  'A2SH4497XM1HET',
#  'A2M0K849FVWZ64',
#  'A2ZFBTGPDP6PH6',
#  'A33VO4F87HEL8D',
#  'A49345VEDY31X',
#  'A2CVVR1UA947XN',
#  'A3W2KQ6CLTQ0ZD',
#  'A1A0G7MJL0HXCO',
#  'A3LLRQH6VA6MU3',
#  'A237BZDL1V5DAO',
#  'A3P7ZVUJRE3O5P',
#  'A1QVJOLW0E85Q2',
#  'AJERUOJ1KR1P3',
#  'A353VHFQ9DDZK0',
#  'A57LKGHRIDR1',
#  'A308UAD6QQ0X0O',
#  'A294O3372JA3OC',
#  'A2RDI91JJM1KPT',
#  'A2JPRN080WBJ4N',
#  'A2PN3GY7I3EKC1',
#  'A1VFUMY02HJIFY',
#  'A1ZC38GBGG8J26',
#  'AB2ZIB3A2UE8W',
#  'A1Y2BG1GPW1VT6',
#  'A2173KL6L6JDZM',
#  'A24Y782XCAQNFJ',
#  'A39YJK1XG5KFDA',
#  'A3SDDMEUMCN858',
#  'A1Z7DJT8JS2ROJ',
#  'A350LAEHRVPHM9',
#  'A1LFIP12CD8N9F',
#  'A23GJP3DRWFPFZ',
#  'A2T7EAV3BL6U3D',
#  'A3W5BERPNVRXR6',
#  'A2XL6TZM34HFV3',
#  'A2TFBYP80N2UAB',
#  'A2LPR8QWLBEQ9O',
#  'A3VJ2N985YRPUS',
#  'A1OHAHOPA4TD80',
#  'ANVQ2KPZUNR4R',
#  'A2YOO8QG992BME',
#  'ADPI2XITU2BZL',
#  'A3AZ44SMA0QNW7',
#  'AOJ632G889T5C',
#  'A2L5QJ9ZSBGWHN',
#  'A219Q7ME4UTC27',
#  'A12J7KCEVA2KND',
#  'A39FYNPLGRP0CL',
#  'A2RWHTNM5P3I8Y',
#  'A1C50N2VRBFS9H',
#  'A1VBJJQ0M08WAD',
#  'A2R9A209Z80BSF',
#  'A2RLQKE9NHSSZB',
#  'A2Z89YMZZJWBHS',
#  'A21MTITRA37SW7',
#  'A2NKYRHYGM9FZW',
#  'AJ0I8H7U2R8YQ',
#  'A14M3S8GUYQNHU',
#  'A2CCGGDGZ694CT',
#  'A3BNU5MEW07D65',
#  'A195EZSQDW3E21',
#  'AFLRU6952DEFX',
#  'A1M1X1KDRLQCVA',
#  'A1Y1RAMLAD5AYZ',
#  'A2TVPR5LBSGKYY',
#  'A1H55L0BLPCWYF',
#  'A31B6K9H98GZMO',
#  'A2QS4AVGBR8748',
#  'A2AD67Z2PNAZ45',
#  'A3V4DQ1L3W6P8Q',
#  'A203OCQQ12MAVT',
#  'A1CCKFD3ZTGT3K',
#  'A21OROF7X9FI7B',
#  'A3PL8ENSYWS1PZ',
#  'A17BIOADPHMEKA',
#  'AO3P8MXILKP5H',
#  'A1K8E597YAFQQG',
#  'A25J3RX2LN6F75',
#  'A2C46HQIZLYJUC',
#  'A0955928C2RRWOWZN7UC',
#  'A1U9Q7K14AG96F',
#  'A32IN6A5QBUGK4',
#  'AV2DN3MW41FDS',
#  'AVPMKKIH917M8',
#  'A3K9OQPCI8UJE',
#  'A2RDNE7NHWYHTD',
#  'A3MH3OS81SQ1XL',
#  'AS41XO2FS4WBA',
#  'AMZ8MTFHMKMAF',
#  'A322QCET1XSLQ9',
#  'A16UCWYG4924HH',
#  'A2A025RLCAQ9HW',
#  'A2BZ5A6PTLKSWT',
#  'A1YE7NIMPEI7G6',
#  'A2JD4LMAKLYR8G',
#  'A2UXFI0HV0TBHR',
#  'A1NYWXYP4AP8KU',
#  'AXUZTYEN1NARA',
#  'A1S52VJWLBRXSN',
#  'AUQ451HTYEEKI',
#  'A1AMWYASBDG21Z',
#  'A2QMNA0ZT6XMRR',
#  'A17OBUF7R058OR',
#  'A2ZAQ3BGD7KI8X',
#  'A3RHOQHFVEVHCR',
#  'A2S1UVZVNE80RM',
#  'A2YGHGJM0YVPN5',
#  'A3DWEBH5YU6VU4',
#  'AGY1Q7NBNXC43',
#  'A2910Q67HYWNLA',
#  'A16EQHBLTTRXRL',
#  'A1RRZ37HAD2QPP',
#  'A21L8WESSSXCP8',
#  'A3NHUK1ISMZCFZ',
#  'A3UOSNSYF9F9PV',
#  'A2AJKYCZ1WC4UP',
#  'A1R4PLLI83D3D4',
#  'A3B1FQR6HV6H42',
#  'A15RRJL2HT44J4',
#  'A2WKXNSHTOOIWL',
#  'ABEMB3JC5VW00',
#  'A2JPECIQW26LCX',
#  'A36QK3OXQZAZC9',
#  'A2PFX6WO88KTYB',
#  'AZX2RDN9YXZAE',
#  'A14UXBBB68V9R0',
#  'ASK39P2ML4Z8K',
#  'A7BTFA87UO4TZ',
#  'A14FMSW73W220M',
#  'A39OW3NJYMRKNP',
#  'A2U65NLR1UNFHF',
#  'A1FLNDIC9076J',
#  'A164BJ2NU1NSJZ',
#  'A14XXL4GMWSI47',
#  'A1H5626CBYYPJX',
#  'A3A8V2LZ1NREE4',
#  'A19SHNFST11PNO',
#  'A20N2TUFC4CMP6',
#  'A30W7EH3AMRXMZ',
#  'A28KMGSM99DQAV',
#  'A2BIKJK1NF86HK',
#  'AQ7Q7O2ZEXKVY',
#  'A5YB62N5KFZT2',
#  'A35PPI93DWFF1H',
#  'AHPSMZ9KPU7EB',
#  'A1UM0RA94H9ZPF',
#  'AZPD2GXU6QFAN',
#  'ATJQOAUHB5XB8',
#  'A27DD549I9B7KI',
#  'A1E45JVA1PYB0D',
#  'AI6QX40JVX5LM',
#  'AZMIKIG4BB6BZ',
#  'A1JCRZEQACX4V4',
#  'A1LH6RF4UN9VI6',
#  'A3UJUX6RZ9WVCB',
#  'ATCBL3A5L2WGT',
#  'AR7O653NMY6QQ',
#  'A1JTDD2GQ66AOO',
#  'A1GM8TOTBWLCTB',
#  'A1A4LJ4WFOT37B',
#  'AWCJ12KBO5VII',
#  'A346HRRKVGLRSI',
#  'A1L8PDZLHQP76K',
#  'AO6VQNF1LLUHM',
#  'A2NYLAJ4PI0CVK',
#  'A3G5M1ZF2AZGMH',
#  'A2ZMKE5T8OQRTX',
#  'A2WBNJP5EFJYMI',
#  'AEZ0X08KA6GPH',
#  ...]

# %%
busiest_reviewer = top10_degree_users[0]

# %%
top_reviewer_data = LLM_attribute(busiest_reviewer)
# Out:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Live Sound & Stage', 'Stage & Studio Cables', 'Microphone Cables'], 'description': ['The CBI MLC Cables are built to last and priced to save you big money! An excellent Low-Z microphone cable, the CBI MLC offers high quality XLR male and female connectors and is compatible with any XLR connection-microphones, mixers, recorders. ..or anywhere else you need a high quality XLR connection.'], 'title': 'CBI MLC LowZ XLR Male to XLR Female Microphone Cable, 20 Feet', 'brand': 'CBI Cables', 'feature': ['Microphone cable for studio recording and live sound', 'High-quality XLR male and female connectors; 3-pin XLR male to XLR female', 'Protective metal housing; flexible PVC jacket with 6.0mm outer diameter', 'All copper conductors and inner copper spiral shielding; shielded cable reduces interference and excess noise', 'Measures 20-feet long; backed by a CBI Cables 10-Year Limited Warranty', '<span class="a-size-base a-color-secondary">\n                Quantity: 1\n            </span>', '<span class="a-size-base a-color-secondary">\n                Length: 20 feet\n            </span>', '<span class="a-size-base a-color-secondary">\n                High Quality XLR Male and Female Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                24-Gauge Wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Flexible Construction\n            </span>', '<span class="a-size-base a-color-secondary">\n                Durable Jacket\n            </span>', '<span class="a-size-base a-color-secondary">\n                Nickel-Plated Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                Model: MLC20\n            </span>'], 'price': '$9.95'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': "This mic cable is AMAZING!  If you plug one end into a mic, and the other end into a PA it can actually CARRY SOUND from one to another!  It's a miracle of modern science.", 'summary': "It's a miracle of modern science."}}, 'Helpful review of product': {'overall': 5.0, 'verified': True, 'reviewText': 'Excellent', 'summary': 'Five Stars'}, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': False, 'reviewText': 'This is four feet long with no dividers or other distinguishing features other than relatively sturdy construction and price.\n\nI can throw four tripod style mic stands in it, or a pair of&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Musician-s-Gear-Standard-Speaker-Stand/dp/B002IVI8P8/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Musician\'s Gear Standard Speaker Stand</a>s that are light weight and fold down to 42 inches. For those uses this is a perfect bag that can easily handle the load.\n\nIn addition to that I also use one of these for my duo gigging kit. I usually accompany a pianist and all I bring is a snare drum and stand, hi-hats and stand, throne, and a pair of brushes. I had been using a&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Stagg-SPSB-SET-5-Professional-Hardware-Carry-Bag/dp/B005LTRCNI/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Stagg SPSB SET 5 Professional Hardware Carry Bag</a>, but I still had to disassemble and reassemble my stands. This bag allows me to literally pull the gear out of the bag, extent the legs and pedal, and mount the drum and cymbals.\n\nIf you have stands that are 48 inches or longer this is NOT the bag for you. If you use light hardware, like the speaker stands I cited above, this is perfect.', 'summary': 'Shorter than most speaker stand bags, but is perfect for other things'}}}
# **************************************************
#
#  Recommendation Justification:
#
# Based on your experience with gear like mic and speaker stands for your performances, this CBI MLC microphone cable is a solid choice for your setup. It's a durable 20-foot cable designed with high-
# quality XLR connectors, perfect for connecting microphones or other audio equipment in the studio or on stage. Other musicians who use gear like yours find these cables reliable for carrying sound, and this particular cable is well-regarded for its quality and build,
#  earning excellent feedback.
# B000VJJQUU-Recommended->A2NYK9KWFMJV4Y edge updated with gemini-2.5-flash-preview-04-17: Based on your experience with gear like mic and speaker stands for your performances, this CBI MLC microphone cable is a solid choice for your setup. It's a durable 20-foot cable designed with high-quality XLR connectors, perfect for connecting microphones or other audio equipment in the studio or on stage. Other musicians who use gear like yours find these cables reliable for carrying sound, and this particular cable is well-regarded for its quality and build, earning excellent feedback.

# %%
two_shot_tip = LLM_attribute(busiest_reviewer, num_product_reviews=2, num_user_reviews=2)
# Out:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Live Sound & Stage', 'Stage & Studio Cables', 'Microphone Cables'], 'description': ['The CBI MLC Cables are built to last and priced to save you big money! An excellent Low-Z microphone cable, the CBI MLC offers high quality XLR male and female connectors and is compatible with any XLR connection-microphones, mixers, recorders. ..or anywhere else you need a high quality XLR connection.'], 'title': 'CBI MLC LowZ XLR Male to XLR Female Microphone Cable, 20 Feet', 'brand': 'CBI Cables', 'feature': ['Microphone cable for studio recording and live sound', 'High-quality XLR male and female connectors; 3-pin XLR male to XLR female', 'Protective metal housing; flexible PVC jacket with 6.0mm outer diameter', 'All copper conductors and inner copper spiral shielding; shielded cable reduces interference and excess noise', 'Measures 20-feet long; backed by a CBI Cables 10-Year Limited Warranty', '<span class="a-size-base a-color-secondary">\n                Quantity: 1\n            </span>', '<span class="a-size-base a-color-secondary">\n                Length: 20 feet\n            </span>', '<span class="a-size-base a-color-secondary">\n                High Quality XLR Male and Female Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                24-Gauge Wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Flexible Construction\n            </span>', '<span class="a-size-base a-color-secondary">\n                Durable Jacket\n            </span>', '<span class="a-size-base a-color-secondary">\n                Nickel-Plated Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                Model: MLC20\n            </span>'], 'price': '$9.95'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Good length and the prices was well within reason. Ends feel tight and secure.', 'summary': 'Five Stars'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': "This mic cable is AMAZING!  If you plug one end into a mic, and the other end into a PA it can actually CARRY SOUND from one to another!  It's a miracle of modern science.", 'summary': "It's a miracle of modern science."}}, 'Helpful review of product': {'overall': 5.0, 'verified': True, 'reviewText': 'Excellent', 'summary': 'Five Stars'}, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': False, 'reviewText': 'I had two of these and wound up selling one because I never used it. The one I kept is currently serving as a keyboard amp for two keyboards (simultaneously): a&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Roland-RD-300NX-Digital-Stage-Piano/dp/B004KCLX8W/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Roland RD-300NX Digital Stage Piano</a>&nbsp;and a&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Roland-V-combo-76-Key-Stage-Keyboard/dp/B0035JDZDC/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Roland V-combo 76 Key Stage Keyboard</a>. I was able to do this because there are two inputs on the front of the amp. Input 1 is designed for normal sensitivity and Input 2 is designed for guitars with active pickups. Thus far I have had no problems with both boards connected at the same time, and it does not seem to matter which board is connected to which input.\n\nThe sound is impressive. Exceptionally clean, and the amp provides controls to allow you to contour your sound, which helps significantly when running keyboards through it.  Moreover, the amp is loud if you choose to make it so, and even at high-gain settings it has ample headroom.\n\nIf you want distortion, this is probably not the amp for you. You can switch it from clean to drive to more drive, but it is essentially still a clean sounding amp. I find this to be a plus, but I have met my share of guitarists who think otherwise.\n\nAnother great feature is you can daisychain these amps using the Pre-Out on the ma ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on your interest in musical equipment
#  like amps and stands, this CBI 20-foot microphone cable could be a useful addition to your setup. Other musicians who bought it found it to be excellent, praising its good length and secure, high-quality XLR connectors. With
#  durable construction and shielded copper conductors designed for clean sound transfer in the studio or on stage, this cable offers reliable performance at a great price, backed by a 10-year warranty.
# B000VJJQUU-Recommended->A2NYK9KWFMJV4Y edge updated with gemini-2.5-flash-preview-04-17: Based on your interest in musical equipment like amps and stands, this CBI 20-foot microphone cable could be a useful addition to your setup. Other musicians who bought it found it to be excellent, praising its good length and secure, high-quality XLR connectors. With durable construction and shielded copper conductors designed for clean sound transfer in the studio or on stage, this cable offers reliable performance at a great price, backed by a 10-year warranty.

# %% [markdown]
# three examples

# %%
three_shot_tip = LLM_attribute(busiest_reviewer, num_product_reviews=3, num_user_reviews=3)
# Out:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Live Sound & Stage', 'Stage & Studio Cables', 'Microphone Cables'], 'description': ['The CBI MLC Cables are built to last and priced to save you big money! An excellent Low-Z microphone cable, the CBI MLC offers high quality XLR male and female connectors and is compatible with any XLR connection-microphones, mixers, recorders. ..or anywhere else you need a high quality XLR connection.'], 'title': 'CBI MLC LowZ XLR Male to XLR Female Microphone Cable, 20 Feet', 'brand': 'CBI Cables', 'feature': ['Microphone cable for studio recording and live sound', 'High-quality XLR male and female connectors; 3-pin XLR male to XLR female', 'Protective metal housing; flexible PVC jacket with 6.0mm outer diameter', 'All copper conductors and inner copper spiral shielding; shielded cable reduces interference and excess noise', 'Measures 20-feet long; backed by a CBI Cables 10-Year Limited Warranty', '<span class="a-size-base a-color-secondary">\n                Quantity: 1\n            </span>', '<span class="a-size-base a-color-secondary">\n                Length: 20 feet\n            </span>', '<span class="a-size-base a-color-secondary">\n                High Quality XLR Male and Female Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                24-Gauge Wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Flexible Construction\n            </span>', '<span class="a-size-base a-color-secondary">\n                Durable Jacket\n            </span>', '<span class="a-size-base a-color-secondary">\n                Nickel-Plated Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                Model: MLC20\n            </span>'], 'price': '$9.95'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Great price and service.', 'summary': 'Five Stars'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'Good length and the prices was well within reason. Ends feel tight and secure.', 'summary': 'Five Stars'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': "This mic cable is AMAZING!  If you plug one end into a mic, and the other end into a PA it can actually CARRY SOUND from one to another!  It's a miracle of modern science.", 'summary': "It's a miracle of modern science."}}, 'Helpful review of product': {'overall': 5.0, 'verified': True, 'reviewText': 'Excellent', 'summary': 'Five Stars'}, 'Reviews of similar products by user': {1: {'overall': 5.0, 'vote': '21', 'verified': True, 'reviewText': 'I purchased this specifically for smaller venues where my other PAs were overkill. I am not going to regurgitate the specs that are on this page, but do want to point out that despite what the product description claims (at the time of this review), this system DOES NOT provide phantom power. If you are using condenser mics you will need a phantom power source or a mic pre amp that provides it.\n\nFor reference I play in a jazz duo and trio, and often with acoustic instruments. So take that into account when I say that this will work for venues of up to fifty people. As such this system is more than sufficient for solo and duo acts. You may be able to use it in larger venues for concerts as opposed to providing background and ambiance music. I have played in small venues where the audience was there for happy hour and chatting among themselves and this system would not work. I have also used it in much larger venues where the audience was there for a concert and this system easily provided the sound level needed to be heard.\n\nOne of the main reasons why I awarded this five stars is sound quality. Although the speakers are small they are rich sounding and can crank out some surprising low end when we run a piano through it. I also love the ability to tailor reverb to three of the channels independent of one another. In fact, you can turn reverb off on one or two cha ...
# **************************************************
#
#  Recommendation Justification:
#
# This CBI microphone cable could be a great addition to your musical setup. Given your experience with various amps and PA systems for live settings, a reliable microphone cable is essential. Other musicians who use this cable highlight its quality XLR connectors and effective shielding to
#  help keep your sound clean by reducing interference. They also commented on its good value, offering a dependable connection for your microphones, mixers, and other gear.
# B000VJJQUU-Recommended->A2NYK9KWFMJV4Y edge updated with gemini-2.5-flash-preview-04-17: This CBI microphone cable could be a great addition to your musical setup. Given your experience with various amps and PA systems for live settings, a reliable microphone cable is essential. Other musicians who use this cable highlight its quality XLR connectors and effective shielding to help keep your sound clean by reducing interference. They also commented on its good value, offering a dependable connection for your microphones, mixers, and other gear.

# %% [markdown]
# four examples

# %%
four_shot_tip = LLM_attribute(busiest_reviewer, num_product_reviews=4, num_user_reviews=4, num_helpful_reviews=2)
# Out:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Live Sound & Stage', 'Stage & Studio Cables', 'Microphone Cables'], 'description': ['The CBI MLC Cables are built to last and priced to save you big money! An excellent Low-Z microphone cable, the CBI MLC offers high quality XLR male and female connectors and is compatible with any XLR connection-microphones, mixers, recorders. ..or anywhere else you need a high quality XLR connection.'], 'title': 'CBI MLC LowZ XLR Male to XLR Female Microphone Cable, 20 Feet', 'brand': 'CBI Cables', 'feature': ['Microphone cable for studio recording and live sound', 'High-quality XLR male and female connectors; 3-pin XLR male to XLR female', 'Protective metal housing; flexible PVC jacket with 6.0mm outer diameter', 'All copper conductors and inner copper spiral shielding; shielded cable reduces interference and excess noise', 'Measures 20-feet long; backed by a CBI Cables 10-Year Limited Warranty', '<span class="a-size-base a-color-secondary">\n                Quantity: 1\n            </span>', '<span class="a-size-base a-color-secondary">\n                Length: 20 feet\n            </span>', '<span class="a-size-base a-color-secondary">\n                High Quality XLR Male and Female Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                24-Gauge Wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Flexible Construction\n            </span>', '<span class="a-size-base a-color-secondary">\n                Durable Jacket\n            </span>', '<span class="a-size-base a-color-secondary">\n                Nickel-Plated Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                Model: MLC20\n            </span>'], 'price': '$9.95'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'A good quality for the money. Using for our sound system at church. You can never have enough patch cables and adapters!', 'summary': 'So far so good!'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'Great price and service.', 'summary': 'Five Stars'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'Good length and the prices was well within reason. Ends feel tight and secure.', 'summary': 'Five Stars'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': "This mic cable is AMAZING!  If you plug one end into a mic, and the other end into a PA it can actually CARRY SOUND from one to another!  It's a miracle of modern science.", 'summary': "It's a miracle of modern science."}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'vote': '3', 'verified': False, 'reviewText': 'This is a thin mat that is easy to fold and comes with both a tie and a bag. It\'s literally grab and go. I love it because it is light weight, reasonably compact (it folds fairly thin) and it actually works.\n\nThe best feature is that noting slips - including the mat itself. One thing to note is if you are using this for a vintage kit with the old disappearing spurs and a bass drum anchor (like the&nbsp;<a data-hook="product-link-linked" class="a-link-normal" href="/Cannon-UP638-Bass-Drum-Anchor/dp/B000AORV3U/ref=cm_cr_arp_d_rvw_txt?ie=UTF8">Cannon UP638 Bass Drum Anchor</a>) you need to reverse the anchor\'s feet to the rubber side, and make sure your spurs are also cupped with rubber or you will shred this mat.\n\nFor my small 18/12/14 jazz kit this is actually a lot bigger than I need. On the other hand I can fit my whole kit, including throne, hihat and floor tom on it with room to spare. The drum carpet I was using before I got this one was a lot smaller so my hihat stand was half on and half off.\n\nPersonally I have found this mat to be both convenient and functional. If something happened to it I would buy another one and that is the best compliment I can pay it.', 'summary': 'Grab and go'}, 2: {'overall': 5.0, 'vote': '21', 'verified ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on your experience with different
#  musical gear, like PA systems and amplifiers, where you value quality and reliable connections, you might appreciate this CBI microphone cable. Musicians similar to you have found these cables offer good quality for the price, noting their secure ends and dependable performance. With
#  high-quality XLR connectors, durable construction, and shielding to reduce noise, this 20-foot cable provides a solid and practical link for your microphones in the studio or on stage, aligning with your preference for reliable connections when using your sound
#  equipment.
# B000VJJQUU-Recommended->A2NYK9KWFMJV4Y edge updated with gemini-2.5-flash-preview-04-17: Based on your experience with different musical gear, like PA systems and amplifiers, where you value quality and reliable connections, you might appreciate this CBI microphone cable. Musicians similar to you have found these cables offer good quality for the price, noting their secure ends and dependable performance. With high-quality XLR connectors, durable construction, and shielding to reduce noise, this 20-foot cable provides a solid and practical link for your microphones in the studio or on stage, aligning with your preference for reliable connections when using your sound equipment.

# %%
five_shot_tip = LLM_attribute(busiest_reviewer, num_product_reviews=5, num_user_reviews=5, num_helpful_reviews=5)
# Out:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Live Sound & Stage', 'Stage & Studio Cables', 'Microphone Cables'], 'description': ['The CBI MLC Cables are built to last and priced to save you big money! An excellent Low-Z microphone cable, the CBI MLC offers high quality XLR male and female connectors and is compatible with any XLR connection-microphones, mixers, recorders. ..or anywhere else you need a high quality XLR connection.'], 'title': 'CBI MLC LowZ XLR Male to XLR Female Microphone Cable, 20 Feet', 'brand': 'CBI Cables', 'feature': ['Microphone cable for studio recording and live sound', 'High-quality XLR male and female connectors; 3-pin XLR male to XLR female', 'Protective metal housing; flexible PVC jacket with 6.0mm outer diameter', 'All copper conductors and inner copper spiral shielding; shielded cable reduces interference and excess noise', 'Measures 20-feet long; backed by a CBI Cables 10-Year Limited Warranty', '<span class="a-size-base a-color-secondary">\n                Quantity: 1\n            </span>', '<span class="a-size-base a-color-secondary">\n                Length: 20 feet\n            </span>', '<span class="a-size-base a-color-secondary">\n                High Quality XLR Male and Female Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                24-Gauge Wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Flexible Construction\n            </span>', '<span class="a-size-base a-color-secondary">\n                Durable Jacket\n            </span>', '<span class="a-size-base a-color-secondary">\n                Nickel-Plated Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                Model: MLC20\n            </span>'], 'price': '$9.95'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Just what I needed.', 'summary': 'Five Stars'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'A good quality for the money. Using for our sound system at church. You can never have enough patch cables and adapters!', 'summary': 'So far so good!'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'Great price and service.', 'summary': 'Five Stars'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'Good length and the prices was well within reason. Ends feel tight and secure.', 'summary': 'Five Stars'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': "This mic cable is AMAZING!  If you plug one end into a mic, and the other end into a PA it can actually CARRY SOUND from one to another!  It's a miracle of modern science.", 'summary': "It's a miracle of modern science."}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': False, 'reviewText': "I've owned this throne for some time and recently purchased a lighter one to further lighten my hardware bag. In less than a month I have come  back to this one for a few reasons.\n\nFirst, it is a lot more comfortable than the lighter one. Although my gigs are in retirement homes and relatively short, I needed something comfortable or risked back pains. This throne had served me well in that respect and is now serving me again after the pains associated with the lighter throne were starting to become more intense.\n\nTo be sure, this is not the best or most comfortable throne for four plus hour gigs and heavy gigging schedules, or even prolonged home and studio use. For those I recommend spending the money for one of the top tier thrones.\n\nI do want to make one correction: the product specs claim that this throne has six adjustable positions - it only has five - so that may be a typo. Still, the range and increments are more than sufficient for most folks. Also, while this uses the older style of tube that is adjustable by inserting a bolt in one of the holes, it is also absolutely non-slip. I own a Tama throne that uses a friction clamp as well as a memo ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on your experience
#  valuing dependable gear for your performances and appreciating quality connections, like you noted with your PA system cables, this CBI microphone cable could be a great fit for your setup. Musicians using this cable have found it offers good quality and value for sound systems, highlighting
#  its reliable XLR connectors and suitability for live use. With features like shielding to reduce noise and a practical 20-foot length, this cable provides the kind of performance and utility you seem to look for in your equipment.
# B000VJJQUU-Recommended->A2NYK9KWFMJV4Y edge updated with gemini-2.5-flash-preview-04-17: Based on your experience valuing dependable gear for your performances and appreciating quality connections, like you noted with your PA system cables, this CBI microphone cable could be a great fit for your setup. Musicians using this cable have found it offers good quality and value for sound systems, highlighting its reliable XLR connectors and suitability for live use. With features like shielding to reduce noise and a practical 20-foot length, this cable provides the kind of performance and utility you seem to look for in your equipment.

# %% [markdown]
# ## Loop

# %% [markdown]
# Running now until we hit the rate limit, going down the list of users by degree.

# %%
gemini_5shot_justifications = LLM_attribute(reviewers_by_degree, num_product_reviews=5, num_user_reviews=5, num_helpful_reviews=5)
# Out:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Live Sound & Stage', 'Stage & Studio Cables', 'Microphone Cables'], 'description': ['The CBI MLC Cables are built to last and priced to save you big money! An excellent Low-Z microphone cable, the CBI MLC offers high quality XLR male and female connectors and is compatible with any XLR connection-microphones, mixers, recorders. ..or anywhere else you need a high quality XLR connection.'], 'title': 'CBI MLC LowZ XLR Male to XLR Female Microphone Cable, 20 Feet', 'brand': 'CBI Cables', 'feature': ['Microphone cable for studio recording and live sound', 'High-quality XLR male and female connectors; 3-pin XLR male to XLR female', 'Protective metal housing; flexible PVC jacket with 6.0mm outer diameter', 'All copper conductors and inner copper spiral shielding; shielded cable reduces interference and excess noise', 'Measures 20-feet long; backed by a CBI Cables 10-Year Limited Warranty', '<span class="a-size-base a-color-secondary">\n                Quantity: 1\n            </span>', '<span class="a-size-base a-color-secondary">\n                Length: 20 feet\n            </span>', '<span class="a-size-base a-color-secondary">\n                High Quality XLR Male and Female Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                24-Gauge Wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Flexible Construction\n            </span>', '<span class="a-size-base a-color-secondary">\n                Durable Jacket\n            </span>', '<span class="a-size-base a-color-secondary">\n                Nickel-Plated Connectors\n            </span>', '<span class="a-size-base a-color-secondary">\n                Model: MLC20\n            </span>'], 'price': '$9.95'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Just what I needed.', 'summary': 'Five Stars'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'A good quality for the money. Using for our sound system at church. You can never have enough patch cables and adapters!', 'summary': 'So far so good!'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'Great price and service.', 'summary': 'Five Stars'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'Good length and the prices was well within reason. Ends feel tight and secure.', 'summary': 'Five Stars'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': "This mic cable is AMAZING!  If you plug one end into a mic, and the other end into a PA it can actually CARRY SOUND from one to another!  It's a miracle of modern science.", 'summary': "It's a miracle of modern science."}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': False, 'reviewText': "I've owned this throne for some time and recently purchased a lighter one to further lighten my hardware bag. In less than a month I have come  back to this one for a few reasons.\n\nFirst, it is a lot more comfortable than the lighter one. Although my gigs are in retirement homes and relatively short, I needed something comfortable or risked back pains. This throne had served me well in that respect and is now serving me again after the pains associated with the lighter throne were starting to become more intense.\n\nTo be sure, this is not the best or most comfortable throne for four plus hour gigs and heavy gigging schedules, or even prolonged home and studio use. For those I recommend spending the money for one of the top tier thrones.\n\nI do want to make one correction: the product specs claim that this throne has six adjustable positions - it only has five - so that may be a typo. Still, the range and increments are more than sufficient for most folks. Also, while this uses the older style of tube that is adjustable by inserting a bolt in one of the holes, it is also absolutely non-slip. I own a Tama throne that uses a friction clamp as well as a memo ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on the type of gear you use, including PA systems where microphone cables are essential, this 20-foot CBI MLC
#  cable could be a great fit for your setup. Musicians who've gotten this cable praise its good quality for the price and the secure feel of its XLR connections, noting it's just what they needed for their sound systems. With features
#  like durable metal housing, a flexible jacket, and inner shielding to reduce noise, this cable is built to provide reliable performance, much like the functional and dependable equipment you've found valuable in the past.
# B000VJJQUU-Recommended->A2NYK9KWFMJV4Y edge updated with gemini-2.5-flash-preview-04-17: Based on the type of gear you use, including PA systems where microphone cables are essential, this 20-foot CBI MLC cable could be a great fit for your setup. Musicians who've gotten this cable praise its good quality for the price and the secure feel of its XLR connections, noting it's just what they needed for their sound systems. With features like durable metal housing, a flexible jacket, and inner shielding to reduce noise, this cable is built to provide reliable performance, much like the functional and dependable equipment you've found valuable in the past.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Strings', 'Electric Guitar Strings'], 'description': ['<div class="aplus"> <div class="two-third-col"> <div class="leftImage" style="width: 350px;"> <div id="image0"><img src="https://images-na.ssl-images-amazon.com/images/I/21jSxZyLwNL.jpg" alt=""></div> </div> <div class="leftImage" style="width: 350px;"> <div id="image1"><img src="https://images-na.ssl-images-amazon.com/images/I/41eOqharcvL.jpg" alt=""></div> </div> <h5><div id="header0">Your Strings Matter.</div></h5> <div id="text0" class="a-spacing-small">', "D'Addario's XL Nickel Wound electric guitar strings are engineered to serve as the critical link between you and your guitar. XL's are precision wound with highly magnetic nickel-plated steel to exacting specifications, resulting in strings with long lasting, distinctive bright tone, and excellent intonation. Ideal for the widest variety of guitars and musical styles, XL's are the choice of countless professionals around the world.", 'The most popular and universal construction, Round Wound strings deliver the traditional textured feel most players are familiar and comfortable with.', 'Renowned for their distinctive, bright tone, XL nickel-plated steel is the industry standard for many genres and playing styles.', "D'Addario Nickel Wound strings are wound with nickelplated steel onto a carefully drawn, hexagonally shaped, high carbon steel core. A high carbon steel alloy that is six-sided in cross section. When usedas the core or center of a musical string, the 6 edge points firmly grip every turn of the wrapwire, ensuring a tight wrap and longer-lasting string.", "It all starts with our exclusively engineered and built string winding machines. There is literally nothing like a D'Addario string machine. The combination of the most advanced computer-controlled winding technology and stringent incoming wire inspection delivers unmatched consistency, string after string, set after set. Every D'Addario string is made in the USA, ensuring the highest quality and performance."], 'title': "D'Addario EXL120+ Nickel Wound Electric Guitar Strings, Super Light Plus, 9.5-44", 'brand': "D'Addario", 'feature': ['"Plus" gauge for improving hand strength, an alternate feel for balancing tension between guitars', 'Round wound with nickelplated steel for distinctive bright tone', 'Corrosion resistant packaging for strings that are always fresh', 'String Gauges: Plain Steel .0095, .0115, .016, Nickel Wound .024, .034, .044', 'Made in the U.S.A. for the highest quality and performance'], 'price': '$4.49'}, 'Reviews by similar users': {1: {'verified': True, 'reviewText': 'great strings', 'overall': 5.0, 'summary': 'Five Stars'}, 2: {'verified': True, 'reviewText': "These are great strings, nice tone, not too bright. The quality is very good and consistent between sets. They hold tuning very well after a little initial stretching and maintain a good tone as long as any other strings I've tried.", 'overall': 5.0, 'summary': 'Great strings, quality product.'}, 3: {'verified': False, 'reviewText': "Excellent strings, D'Addario's quality has always been even and reliable. Of course, there are other excellent options but I usually wind up with D'Addario on all my guitars.", 'overall': 5.0, 'summary': "Been using D'Addario's for decades."}, 4: {'verified': False, 'reviewText': "Love em, So will you. Nice warm sound when I want. D'Addario are excellent strings. They do sound great on my semi hollow Hagstrom Viking Deluxe Tremor and they hold their tone very well. Try em yourself. I don't think you will be disappointed.\n\nI will recommend these to my friends. Been playing many years. Let your fingers try em out. You'll dig em.", 'overall': 5.0, 'summary': 'A great set of strings, no matter how accomplished your guitar playing is.'}, 5: {'verified': True, 'reviewText': 'Excelente', 'overall': 5.0, 'summary': 'Excelente'}}, 'Helpful review of  ...
# **************************************************
#
#  Recommendation Justification:
#
# Here are the D'Addario EXL120+ electric guitar strings in the Super Light Plus gauge. Other guitarists like you have found
#  these sets to be excellent quality, offering consistent performance with nice tone and tuning stability that lasts. D'Addario is widely regarded for making reliable strings, crafted in the USA using advanced techniques like precision winding onto a hexagonal high carbon steel core for
#  durability and a consistent bright sound. This specific "Plus" gauge (.0095-.044) also offers a slightly different feel and tension balance, a thoughtful detail that contributes to the high-quality design you appreciate in musical
#  gear.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Strings', 'Electric Guitar Strings'], 'description': ['<div class="aplus"> <div class="two-third-col"> <div class="leftImage" style="width: 350px;"> <div id="image0"><img src="https://images-na.ssl-images-amazon.com/images/I/21jSxZyLwNL.jpg" alt=""></div> </div> <div class="leftImage" style="width: 350px;"> <div id="image1"><img src="https://images-na.ssl-images-amazon.com/images/I/41eOqharcvL.jpg" alt=""></div> </div> <h5><div id="header0">Your Strings Matter.</div></h5> <div id="text0" class="a-spacing-small">', "D'Addario's XL Nickel Wound electric guitar strings are engineered to serve as the critical link between you and your guitar. XL's are precision wound with highly magnetic nickel-plated steel to exacting specifications, resulting in strings with long lasting, distinctive bright tone, and excellent intonation. Ideal for the widest variety of guitars and musical styles, XL's are the choice of countless professionals around the world.", 'The most popular and universal construction, Round Wound strings deliver the traditional textured feel most players are familiar and comfortable with.', 'Renowned for their distinctive, bright tone, XL nickel-plated steel is the industry standard for many genres and playing styles.', "D'Addario Nickel Wound strings are wound with nickelplated steel onto a carefully drawn, hexagonally shaped, high carbon steel core. A high carbon steel alloy that is six-sided in cross section. When usedas the core or &#xE2;&#x20AC;&#x153;center&#xE2;&#x20AC;&#x9D; of a musical string, the 6 edge points firmly grip every turn of the wrapwire, ensuring a tight wrap and longer-lasting string.", "It all starts with our exclusively engineered and built string winding machines. There is literally nothing like a D'Addario string machine. The combination of the most advanced computer-controlled winding technology and stringent incoming wire inspection delivers unmatched consistency, string after string, set after set. Every D'Addario string is made in the USA, ensuring the highest quality and performance."], 'title': "D'Addario EXL120-7 Nickel Wound 7-String Electric Guitar Strings, Super Light, 9-54", 'brand': "D'Addario", 'feature': ['Super light 7-string gauges for maximum flexibility and biting tone', 'Round wound with nickelplated steel for distinctive bright tone', 'Corrosion resistant packaging for strings that are always fresh', 'String Gauges: Plain Steel .009, .011, .016, Nickel Wound .024, .032, .042 , .054', 'Made in the U.S.A. for the highest quality and performance'], 'price': '$5.99'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'I will try Circle K strings on this guitar next time.  I really like the Circle Ks on my RG2228A.', 'summary': 'Sound Great on my Jem7V7'}, 2: {'overall': 5.0, 'vote': '2', 'verified': True, 'reviewText': "I buy these in 10 packs and use them on my three main guitars because they're the absolute best: best tone, longest lasting, excellent feel. For me D'addario strings rule. And when you buy the 10 packs they're cheap as free I have 20 sets of XLs and 10 sets of NYXLs in the studio closet right now: I guess I've decided that I'm using D'addarios for a long time to come.", 'summary': 'The Very Best.'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': "The 9.5's helped manage a situation with a custom build. 25.5 scale length Tele neck with a TOM bridge set up. 10's were too clumsy on this double cut Tele but before I tried more drastic measures, the 9.5's maintained a good action and increased playability nicely.\n\nAfter a year and repurchase, I'm still in love with these strings. Good life over 3-4 sweaty gigs, response and tone is consistent.\nI'm so glad they aren't 9's !!!", 'summary': "5's maintained a good action and increased playability nicely"}, 4: {'overall': 5.0, 'verified': True, 'reviewText': "I've been trying out d ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on your positive experiences with similar gear, you might really enjoy these D'Addario EXL120-7 electric guitar strings. Players find these 7-string Super Light 9-54 gauge strings
#  deliver a distinctive bright tone and excellent intonation. Customers who play similar guitars mention they have great feel, last a long time, and stay in tune quickly, making them a popular choice for many styles.
# B0002E3CK4-Recommended->A3YVD62FSVIUJ edge updated with gemini-2.5-flash-preview-04-17: Based on your positive experiences with similar gear, you might really enjoy these D'Addario EXL120-7 electric guitar strings. Players find these 7-string Super Light 9-54 gauge strings deliver a distinctive bright tone and excellent intonation. Customers who play similar guitars mention they have great feel, last a long time, and stay in tune quickly, making them a popular choice for many styles.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Strings', 'Electric Guitar Strings'], 'description': ['<div class="aplus"> <div class="two-third-col"> <div class="leftImage" style="width: 350px;"> <div id="image0"><img src="https://images-na.ssl-images-amazon.com/images/I/21jSxZyLwNL.jpg" alt=""></div> </div> <div class="leftImage" style="width: 350px;"> <div id="image1"><img src="https://images-na.ssl-images-amazon.com/images/I/41eOqharcvL.jpg" alt=""></div> </div> <h5><div id="header0">Your Strings Matter.</div></h5> <div id="text0" class="a-spacing-small">', "D'Addario's XL Nickel Wound electric guitar strings are engineered to serve as the critical link between you and your guitar. XL's are precision wound with highly magnetic nickel-plated steel to exacting specifications, resulting in strings with long lasting, distinctive bright tone, and excellent intonation. Ideal for the widest variety of guitars and musical styles, XL's are the choice of countless professionals around the world.", 'The most popular and universal construction, Round Wound strings deliver the traditional textured feel most players are familiar and comfortable with.', 'Renowned for their distinctive, bright tone, XL nickel-plated steel is the industry standard for many genres and playing styles.', "D'Addario Nickel Wound strings are wound with nickelplated steel onto a carefully drawn, hexagonally shaped, high carbon steel core. A high carbon steel alloy that is six-sided in cross section. When usedas the core or center of a musical string, the 6 edge points firmly grip every turn of the wrapwire, ensuring a tight wrap and longer-lasting string.", "It all starts with our exclusively engineered and built string winding machines. There is literally nothing like a D'Addario string machine. The combination of the most advanced computer-controlled winding technology and stringent incoming wire inspection delivers unmatched consistency, string after string, set after set. Every D'Addario string is made in the USA, ensuring the highest quality and performance."], 'title': "D'Addario EJ21 Nickel Wound Electric Guitar Strings, Jazz Light, 12-52", 'brand': "D'Addario", 'feature': ['Features a wound 3rd/G string, optimal for "jazz" style playing', 'Round wound with nickelplated steel for distinctive bright tone', 'String Gauges; Plain steel .012, .016, Nickel Wound .024, .032, .042, .052', 'Corrosion resistant packaging for fresh strings, always!', 'Made in the U.S.A. for the highest quality and performance'], 'price': '$4.99'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': "What bad could you say about D'Addario!", 'summary': "What bad could you say about D'Addario!"}, 2: {'overall': 5.0, 'verified': False, 'reviewText': "I replaced a set of Ernie Ball's with these on a Strat. The D'Addarios sound thinner and warmer at the same time. The sound reminded me of a steel string acoustic. It's a nice sound that some will prefer and others won't. I strongly recommend trying them, since they do make a difference and you might fall in love with them.", 'summary': 'Distinctive tone worth checking out'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': "Instant tone magic. these are the thing you're looking for.", 'summary': 'The best.'}, 4: {'overall': 5.0, 'verified': False, 'reviewText': 'Good strings, that last quite awhile. I like the weight of these, they are not really heavy, but not so light that they feel weird either. They are really easy to push down and do bar chords with, but also not too heavy for bending can easily bend the 2nd string a step even a step and a half if you try.', 'summary': "D'Addario strings are nice."}, 5: {'overall': 5.0, 'verified': True, 'reviewText': 'Excelente', 'summary': 'Excelente'}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'vote': '7', 'verified': False, 'reviewText': 'This review is f ...
# **************************************************
#
#  Recommendation Justification:
#
# As a musician who clearly values quality gear and nuanced sound, you might find these D'Addario EJ21 Nickel Wound electric guitar strings a great choice
# . Other players consistently highlight D'Addario for their reliable performance and feel, noting the distinctive bright tone that can offer "instant tone magic" and comfortable playability even with heavier gauges. Designed with a wound G string, these strings are
#  particularly suited for players exploring 'jazz' styles, offering the durability and consistent output that discerning musicians, like yourself, appreciate in their equipment.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Strings', 'Acoustic Guitar Strings'], 'description': ["Prolong your tone with the same acoustic guitar strings that experienced players worldwide trust to keep their incredible tone longer than any other string available. Unlike other string brands, Elixir Strings coats the whole string. This protects not only the outer string surface but also the gaps between the windings where common tone-deadening gunk typically builds up in other brands coated and uncoated guitar strings. Anti-Rust Plating on plain steel strings ensures longer tone life for the entire set. Who wouldnt love more quality playing time between the hassle and cost of string changes? Premium by design, these acoustic strings constructed with 80/20 (80% copper, 20% zinc) bronze wrap wire boast a crisp, bright tone with an expressive, vibrant presence. Compared to our original POLYWEB Coating, the ultra-thin NANOWEB Coating allows a more traditionally textured, uncoated feel. The HD Light gauge option you're looking at now, originally developed with Taylor Guitars for their Grand Concert and Grand Auditorium models, is an expertly unique set of gauges for all sorts of guitars, exuding a balanced voice across the strings that's bold and articulate on the high end without sacrificing a rich, full low end. For a slicker, gentler feel, try the original POLYWEB Coating on our 80/20 Bronze Acoustic Strings, which also feature a more robust and rounded tone. For more of a balance between bold and bright, our Phosphor Bronze Acoustic Guitar Strings with NANOWEB Coating deliver full-bodied tone and sparkling high-end clarity alongside the same traditional feel as these 80/20 bronze strings. Of course, the kind of string you play is all a matter of personal preference. Not sure what tone or feel is right for you? Try them out for yourself, and find your new favorite string from Elixir Strings. For a more in-depth look at what makes our strings so special, scroll to the branded info further down the page. Elixir Strings: Great tone. Long life."], 'title': 'Elixir Strings 80/20 Bronze Acoustic Guitar Strings w NANOWEB Coating, HD Light (.013-.053)', 'brand': 'Elixir', 'feature': ['Acoustic guitar strings constructed with 80/20 (80% copper, 20% zinc) bronze wrap wire', 'Played for a crisp, bright tone with an expressive, vibrant presence', 'Ultra-thin NANOWEB Coating provides a more traditionally textured, uncoated feel', 'Our patented coating technology protects against common corrosion, extending tone life longer than any other brands coated or uncoated strings (Elixir Strings player survey)', 'HD Light gauge: .013 .017 .025 .032 .042 .053 (specially developed with Taylor Guitars for a bolder high end and fuller low end)', '<span class="a-size-base a-color-secondary">\n                Electric Guitar Strings\n            </span>', '<span class="a-size-base a-color-secondary">\n                Bass Guitar Strings\n            </span>', '<span class="a-size-base a-color-secondary">\n                Banjo Strings\n            </span>', '<span class="a-size-base a-color-secondary">\n                Mandolin Strings\n            </span>', '<span class="a-size-base a-color-secondary">\n                Elixir Strings 80/20 Bronze Acoustic Guitar Strings w POLYWEB Coating\n            </span>', '<span class="a-size-base a-color-secondary">\n                Elixir Strings Phosphor Bronze Acoustic Guitar Strings w NANOWEB Coating\n            </span>', '<span class="a-size-base a-color-secondary">\n                Elixir Strings 80/20 Bronze Acoustic Guitar Strings w NANOWEB Coating\n            </span>'], 'price': '$12.55'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Great strings------ good sound--------  good price  Thank you I wll get more in the future. Elixers last longer than other strings I have them on all of my guitars and mandolin', ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on what other players who enjoy similar gear say, these Elixir acoustic guitar strings come highly recommended. Many find they
#  offer excellent sound quality with rich bass tones and clear articulation, and they particularly appreciate how long the strings last, making them a worthwhile investment for your instrument. Players also mention they feel softer and more comfortable under their fingers compared to other strings.
#
# An error occurred during content generation: can only concatenate str (not "NoneType") to str
# B00J4TBMVO-Recommended->A2SUG35F6A6S3C edge updated with gemini-2.5-flash-preview-04-17: Based on what other players who enjoy similar gear say, these Elixir acoustic guitar strings come highly recommended. Many find they offer excellent sound quality with rich bass tones and clear articulation, and they particularly appreciate how long the strings last, making them a worthwhile investment for your instrument. Players also mention they feel softer and more comfortable under their fingers compared to other strings.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Tuners'], 'description': ['Guitar, Bass and Violin Tuner'], 'title': 'Snark SN-5 Tuner for Guitar, Bass and Violin (Black)', 'brand': 'Snark', 'feature': ['Full Color Display', 'Display rotates 360 degrees for easy viewing', 'Features frequency range tailored to guitar and bass', 'Tuner can be used on front of back of headstock'], 'price': '$12.20'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': "This is my second purchase of one of these. I love this little beauty. IMHO.. you'd be really hard pressed to find a better tuner, regardless of price.", 'summary': 'I love this little beauty'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'Nice addition to the collection!', 'summary': 'Very Accurate'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'it worked as I figured it would. They want you to say more about the product than I want to say.', 'summary': 'Nice item'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': "This is the only tuner I use because of the vibration tuning. You can't beat it for acoustic guitar or violin.", 'summary': 'Great tuner!'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': 'works great', 'summary': 'Five Stars'}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Just as described in their ad.  SW', 'summary': 'BEST FORYOUR DOLLAR!!'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': "This is a well made item, shipped fast. But I haven't tried it out yet. I'm a drummer sense 1965, you will like it.  SW", 'summary': 'BEST FOR YOUR DOLLAR!!'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'The item came just as it was described. It was a good price as well. Packed well.  SW', 'summary': 'BEST FOR YOUR DOLLAR!!'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'The item came as described. Packed well, and  was a good price to pick up on Amazon.  SW', 'summary': 'BEST FOR YOUR DOLLAR!!'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': "Well I bought this Guitar, with great thoughts in front of me. It is light hot, great color. But only 22 frets, not 24 as said in it's description. That's the only bad thing THAT I can say about this guitar folks. It is well made. Packed well, came fast.  SW", 'summary': 'BEST FOR YOUR DOLLAR!!'}}}
# **************************************************
#
#  Recommendation Justification:
#
# Based on feedback from other musicians, this Snark SN
# -5 tuner is highly recommended for its accuracy and ease of use on guitar, bass, and violin. Many players appreciate its clear, rotating color display and find it offers exceptional value. Given your positive experiences with other instrument gear you've described as "
# BEST FOR YOUR DOLLAR!!" and your focus on finding accurate items, this well-regarded and versatile tuner seems like a great addition to your collection.
# B004XNK7AI-Recommended->AZV2U6GU5QA6C edge updated with gemini-2.5-flash-preview-04-17: Based on feedback from other musicians, this Snark SN-5 tuner is highly recommended for its accuracy and ease of use on guitar, bass, and violin. Many players appreciate its clear, rotating color display and find it offers exceptional value. Given your positive experiences with other instrument gear you've described as "BEST FOR YOUR DOLLAR!!" and your focus on finding accurate items, this well-regarded and versatile tuner seems like a great addition to your collection.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar &amp; Bass Accessories', 'Strings', 'Acoustic Guitar Strings'], 'description': ['25 SETS EJ17 PHOS BRONZE MED', '', 'EJ17s offer heavier tension resulting in a bolder, more resonant acoustic tone with higher resistance for heavy strumming and flat-picking. Containing 25 sets of bulk packaged strings, the EJ17-B25 Bulk Shop is ideal for guitarists with multiple guitars or anyone that demands the freshest strings at a great value.', "Phosphor Bronze was introduced to string making by D'Addario in 1974 and has become synonymous with warm, bright, and well balanced acoustic tone. D'Addario Phosphor Bronze strings are precision wound with corrosion resistant phosphor bronze onto a carefully drawn, hexagonally shaped, high carbon steel core. The result is long lasting, bright sounding tone with excellent intonation.", "D'Addario, the world's largest manufacturer of musical instrument strings, is known as The Players Choice with a reputation for unsurpassed quality and consistency. D'Addario's innovative packaging reduces waste and provides protection from corrosion. All D'Addario strings are manufactured in the U.S.A. using proprietary, digitally controlled, state-of-the-art machinery for unmatched performance, set after set.", ''], 'title': "D'Addario EJ17-B25 Phosphor Bronze Acoustic Guitar Strings, Medium, 13-56, 25 Bulk Sets", 'brand': "D'Addario", 'feature': ["D'Addario's most popular choice for heavy strumming, flat-picking and resonant, projecting tone in a convenient bulk pack of 25 sets", 'Preferred for its warm, bright, and well balanced acoustic tone', 'Bulk shop packaging is ideal for workbenches or anywhere bulk packaged strings are needed', 'Made in the U.S.A. for the highest quality and performance', 'String Gauges: Plain Steel .013, .017, Phosphor Bronze Wound .026, .035, .045, .056', '<span class="a-size-base a-color-secondary">\n                The worlds most popular acoustic guitar string\n            </span>', '<span class="a-size-base a-color-secondary">\n                Warm tone\n            </span>', '<span class="a-size-base a-color-secondary">\n                High carbon steel core and plain steel wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Gauges ranging from Extra Light to Medium\n            </span>'], 'price': '$139.99'}, 'Reviews by similar users': {1: {'verified': True, 'reviewText': 'Long lasting and good sound', 'overall': 5.0, 'summary': 'dig these strings'}, 2: {'verified': False, 'reviewText': 'Husband likes these strings.  He has stayed with this brand for years!  Might have to buy stock in these as much as he goes through strings!', 'overall': 5.0, 'summary': 'Great Strings'}, 3: {'verified': True, 'reviewText': 'I hate writing reviews but these are my favorite strings.  Fellow players always ask what I am playing with as the sound is so sweet.  Highly recommend.', 'overall': 5.0, 'summary': 'I hate writing reviews but these are my favorite strings'}, 4: {'verified': True, 'reviewText': 'Durable and sounds good.', 'overall': 5.0, 'summary': 'Five Stars'}, 5: {'verified': True, 'reviewText': 'Great strings, sound great, and last a while!', 'overall': 5.0, 'summary': 'Five Stars'}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'vote': '2', 'verified': False, 'reviewText': "I purchased the dispatch master through my local music store after watching several videos on YouTube about it and trying it out. It is an excellent sounding reverb/delay. Either effect can be used separately, but where this pedal really shines is when you use the effects together. It creates a wonderful wash of tone beneath your playing and is great for the type of music I mostly play: Praise and Worship.\n\nThe dispatch master does a great job of keeping your signal above the effected signal. I believe this has something to do with the pre-delay o ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on your appreciation for gear that delivers excellent sound quality and
#  reliable performance, like your delay and reverb pedals, you may find these D'Addario Phosphor Bronze acoustic strings a great fit for your guitar. Players who prefer this set often highlight their warm, bright, and well-balanced acoustic tone, noting
#  how they produce a bold, resonant sound that's great for strumming and flat-picking. Many users also report that these strings offer good durability and maintain their sweet sound for a long time, aligning with your likely preference for quality instruments and
#  accessories.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Tuners'], 'description': ['Guitar, Bass and Violin Tuner'], 'title': 'Snark SN-5 Tuner for Guitar, Bass and Violin (Black)', 'brand': 'Snark', 'feature': ['Full Color Display', 'Display rotates 360 degrees for easy viewing', 'Features frequency range tailored to guitar and bass', 'Tuner can be used on front of back of headstock'], 'price': '$12.20'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': "couldn't get the tuning correct without this handy tool.", 'summary': 'Five Stars'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'works as advertised, is cheap plastic but 7 bucks what do you expect?', 'summary': 'Five Stars'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'Works amazingly well, is very precise, and easy to handle. I have seen other devices that would get confused about frequencies and jump back and forth between different notes. Not so this one. It is a great, reliable tuner.', 'summary': 'Great tuner'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'For being so cheap especially. I play upright & it does a great job! Clips on fast, responds fast, then on with the night.', 'summary': 'Very impressive!!'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': 'it worked as I figured it would. They want you to say more about the product than I want to say.', 'summary': 'Nice item'}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': True, 'reviewText': "Nice, inexpensive bridge pins to replace an old set of worn, mismatched pins.\nThese fit snug and look good.  A very inexpensive way to improve how your guitar looks.\nI can't believe how many guitars out there have broken or mismatched pins in them when these are so inexpensive.\nOh well, I like things right and these do what they are supposed to.", 'summary': 'Exactly what I expected'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': "These are great to have.  I use them as a second Strap button for my acoustics that only come with one.  I hate playing an acoustic with a tie wrap at the top.  I don't understand why some manufacturers don't add the button, especially high end guitars like my Martin.  I was reluctant to drill a hole to install this on my Martin but now I am so glad I did.  These are perfect.", 'summary': 'These are great to have'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': "I purchased this gig bag for my Ovation Acoustic Electric.  For those of you who know how large Ovations are and the odd shape they have, it does fit comfortably in the bag.  There is plenty of room in the bag for the guitar and to store extra strings, music books, tuner and everything else you'd need to play.\nThe bag looks nice, is very sturdy ad lightweight.  The zippers work well with no sticking.\nThe only negative I can think of is the price.  This gig bag I thought was a bit expensive for what it is.\nI would probably purchase a different bag if I could do it again only because I don't think I will use this often enough to justify the price I paid.  BUT, if you plan on using this a lot and even taking it on flights, this bag would be a good choice.", 'summary': 'GREAT gig bag'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'I purchased a show case for my prized possession, my new Gibson Lucille.  I had BB King sign it for me and it\'s now cradled in this swing inside the case over my couch.  This worked out well after doing a few modifications to make it fit inside the case.  It works though and looks good.  If you are going to just hang a guitar on the wall, this is perfect with no modifications needed.\nIf I trust my "Lucille" probably valued well in excess of 10 grand in it, you should too.\nThis was padded in all of the right places so my prize won\'t get scratched.', 'summary': 'Perfect of my "Lucille"'}, 5: {'overall': 5.0, 'verified': Tru ...
# **************************************************
#
#  Recommendation Justification:
#
# Based on your interest in practical and effective accessories for your instruments, you
#  might like the Snark SN-5 Tuner. It's a popular choice among musicians looking to accurately tune their guitar or bass quickly and reliably. Other players praise its precise tuning, ease of use with a bright color display, and great value
# , which seems to align with the kind of useful additions you've chosen for your gear in the past. It's specifically designed for guitar and bass frequencies and is very affordable, making it a handy tool for keeping your instruments sounding their best.
# B004XNK7AI-Recommended->A15TYOEWBQYF0X edge updated with gemini-2.5-flash-preview-04-17: Based on your interest in practical and effective accessories for your instruments, you might like the Snark SN-5 Tuner. It's a popular choice among musicians looking to accurately tune their guitar or bass quickly and reliably. Other players praise its precise tuning, ease of use with a bright color display, and great value, which seems to align with the kind of useful additions you've chosen for your gear in the past. It's specifically designed for guitar and bass frequencies and is very affordable, making it a handy tool for keeping your instruments sounding their best.
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar &amp; Bass Accessories', 'Tools'], 'description': ['', "Most ordinary peg winders serve the single basic purpose of winding the tuning pegs of a guitar during string changes, but the Planet Waves Pro-Winder isn't any ordinary peg winder.", "The ergonomic design of the Pro-Winder makes string changes easier than ever before with it's built-in clippers, bridge pin puller, and peg winder all rolled into one product. The peg winder is also designed to fit on virtually all guitars, banjos, and mandolins, truly making it a must have for every instrument case.", 'The patented Pro-Winder design is also available for bass guitar. With a handle designed for efficient and comfortable use and a peg winder that fits both vintage and modern basses, the Bass Pro-Winder has you covered. The hardened steel clippers are also tough enough to cut through bass strings with ease.', 'Designed to work for a wide variety of fretted instruments, the Pro-Winder for guitar is a perfect all-in-one tool for every player to keep in their gig bag or case. The Pro-Winder is the Swiss Army knife of string changing.', 'The Bass Pro-Winder takes the user friendly and ergonomic elements of the original Pro-Winder and makes them applicable for both vintage and modern bass guitar tuning pegs.', 'With the hardened steel clippers on the Pro-Winders string cutter you can cut through your old strings to make removing them quicker, and trim the excess off of new strings after looping them through the tuning machines.', 'When it comes to bass guitar you are dealing with some pretty heavy gauge strings. The good news is that the hardened steel clippers of the Bass Pro-Winders string cutter are specifically designed to easily cut through the thickest of strings.', 'Designed with acoustic guitarists in mind, the Pro-Winder also has a built in bridgepin puller. This makes removing stubborn pins simple without risking damage caused by pliers and other tools.', 'The Bass Pro-Winder is designed to seat itself on a variety of peg winder sizes and shapes. The spinning head and comfortable handle make changing bass strings a much simpler and efficient process.', ''], 'title': 'DAddario Accessories Pro-Winder Guitar String Winder and Cutter  All-In-1 Restringing Tool  Includes Clippers, Bridge Pin Puller, Peg Winder  Designed to Fit Most Guitars', 'brand': "D'Addario Accessories", 'feature': ["ALL-IN-ONE RESTRINGING TOOL - The ergonomic and high-quality design of the D'Addario Accessories Pro-Winder makes string changes quicker and easier than ever before with its built-in clippers, bridge pin puller and peg winder all rolled into one tool.", 'MUST HAVE FOR EVERY CASE  Why fill up your case with three tools when you can have one that does it all? This indispensable tool has been designed to fit comfortably in your hand and for use on virtually all electric and acoustic guitars, basses, banjos and mandolins. Also available in a bass guitar version.', 'BUILT-IN STRING CUTTER  With the hardened steel clippers on the Pro-Winder string cutter you can cleanly cut through your old strings to remove them quicker and easier, and trim the excess off new strings after looping them through the tuning machines.', 'INTEGRATED BRIDGE PIN PULLER- Designed with acoustic guitarists in mind, the Pro-Winder has a built-in bridge pin puller. This makes removing stubborn pins simple without risking damage caused by pliers and other tools.', "MADE IN THE USA - D'Addario Accessories is known for innovative, problem-solving, quality musical accessories that are proudly designed, engineered, and manufactured in the USA to the most stringent quality controls in the industry.", '<span class="a-size-base a-color-secondary">\n                High-Quality peg winder with built-in string cutter.\n            </span>', '<span class="a-size-base a-color-secondary">\n                Ergonomically designed for efficient and comfortable ...
# **************************************************
#
#  Recommendation Justification:
#
# This D'Addario Pro-Winder tool could be a really handy addition to your instrument accessories. Like other players, you'll probably find that having a string winder,
#  cutter, and bridge pin puller all in one makes restringing your guitars or other instruments much faster and simpler. It's a versatile, practical tool designed to take care of different tasks efficiently, which could fit well with your enjoyment of reliable gear
#  for playing and maintaining your instruments.
# B0002E1G5C-Recommended->A1FOXJ8TMYVKRK edge updated with gemini-2.5-flash-preview-04-17: This D'Addario Pro-Winder tool could be a really handy addition to your instrument accessories. Like other players, you'll probably find that having a string winder, cutter, and bridge pin puller all in one makes restringing your guitars or other instruments much faster and simpler. It's a versatile, practical tool designed to take care of different tasks efficiently, which could fit well with your enjoyment of reliable gear for playing and maintaining your instruments.
# **************************************************
#
# Raw Info:
#
# ...
# **************************************************
#
#  Recommendation Justification:
#
#
# An error occurred during content generation: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '500'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '8s'}]}}
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Strings', 'Acoustic Guitar Strings'], 'description': ['.011-.052 Custom Light Gauge Acoustic Guitar Strings, Phosphor Bronze'], 'title': "D'Addario EJ26 Phosphor Bronze Acoustic Guitar Strings, Custom Light, 11-52", 'brand': "D'Addario", 'feature': ["A D'Addario hybrid gauge, combining light gauge bottom strings with lighter top strings for easy bending", 'Preferred for its warm, bright, and well balanced acoustic tone', 'Corrosion resistant packaging for strings that are always fresh', 'Made in the U.S.A. for the highest quality and performance', 'String Gauges: Plain Steel .011, .015, Phosphor Bronze Wound .022, .032, .042, .052; Set of Six strings Musical Notes E,B,G,D,A,E -', '<span class="a-size-base a-color-secondary">\n                The worlds most popular acoustic guitar string\n            </span>', '<span class="a-size-base a-color-secondary">\n                Warm tone\n            </span>', '<span class="a-size-base a-color-secondary">\n                High carbon steel core and plain steel wire\n            </span>', '<span class="a-size-base a-color-secondary">\n                Gauges ranging from Extra Light to Medium\n            </span>'], 'price': '$6.99'}, 'Reviews by similar users': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'These are the only strings I use on my acoustic/electric. Love the sealed bags to keep the air tight seal. Prefer the Extra lights.', 'summary': 'Love Love Love'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': "I like D'Addario strings.  They last long and sound good all the time.  Plus, they are the strings that Takamine puts on their new instruments.", 'summary': 'Great strings'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'Awesome, thank you for the bargain. I have been a musician for thirty years now my kids are joining in. Great deal.', 'summary': 'Awesome, thank you for the bargain'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'nice sound. feel good to finger or pick.', 'summary': 'good tunes'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': 'Great strings, sound great, and last a while!', 'summary': 'Five Stars'}}, 'Helpful review of product': None, 'Reviews of similar products by user': {1: {'overall': 5.0, 'verified': True, 'reviewText': 'Item as expected, great value.', 'summary': 'Item as expected, great value.'}, 2: {'overall': 5.0, 'verified': True, 'reviewText': 'Item as described', 'summary': 'Five Stars'}, 3: {'overall': 5.0, 'verified': True, 'reviewText': 'Item as expected, great value.', 'summary': 'Item as expected, great value.'}, 4: {'overall': 5.0, 'verified': True, 'reviewText': 'Best wah wah ever!!!!', 'summary': 'Morley GL wah F*&^%nin Rocks!!'}, 5: {'overall': 5.0, 'verified': True, 'reviewText': 'Item as described', 'summary': 'Five Stars'}}}
# **************************************************
#
#  Recommendation Justification:
#
#
# An error occurred during content generation: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '500'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '7s'}]}}
# B0002H0A3S-Recommended->A345PWU4ST401I edge updated with gemini-2.5-flash-preview-04-17:
# **************************************************
#
# Raw Info:
#
# {'Product': {'category': ['Musical Instruments', 'Instrument Accessories', 'Guitar & Bass Accessories', 'Strings', 'Electric Guitar Strings'], 'description': ['<div class="aplus"> <div class="two-third-col"> <div class="leftImage" style="width: 350px;"> <div id="image0"><img src="https://images-na.ssl-images-amazon.com/images/I/21jSxZyLwNL.jpg" alt=""></div> </div> <div class="leftImage" style="width: 350px;"> <div id="image1"><img src="https://images-na.ssl-images-amazon.com/images/I/41eOqharcvL.jpg" alt=""></div> </div> <h5><div id="header0">Your Strings Matter.</div></h5> <div id="text0" class="a-spacing-small">', "D'Addario's XL Nickel Wound electric guitar strings are engineered to serve as the critical link between you and your guitar. XL's are precision wound with highly magnetic nickel-plated steel to exacting specifications, resulting in strings with long lasting, distinctive bright tone, and excellent intonation. Ideal for the widest variety of guitars and musical styles, XL's are the choice of countless professionals around the world.", 'The most popular and universal construction, Round Wound strings deliver the traditional textured feel most players are familiar and comfortable with.', 'Renowned for their distinctive, bright tone, XL nickel-plated steel is the industry standard for many genres and playing styles.', "D'Addario Nickel Wound strings are wound with nickelplated steel onto a carefully drawn, hexagonally shaped, high carbon steel core. A high carbon steel alloy that is six-sided in cross section. When usedas the core or center of a musical string, the 6 edge points firmly grip every turn of the wrapwire, ensuring a tight wrap and longer-lasting string.", "It all starts with our exclusively engineered and built string winding machines. There is literally nothing like a D'Addario string machine. The combination of the most advanced computer-controlled winding technology and stringent incoming wire inspection delivers unmatched consistency, string after string, set after set. Every D'Addario string is made in the USA, ensuring the highest quality and performance."], 'title': "D'Addario EXL120+ Nickel Wound Electric Guitar Strings, Super Light Plus, 9.5-44", 'brand': "D'Addario", 'feature': ['"Plus" gauge for improving hand strength, an alternate feel for balancing tension between guitars', 'Round wound with nickelplated steel for distinctive bright tone', 'Corrosion resistant packaging for strings that are always fresh', 'String Gauges: Plain Steel .0095, .0115, .016, Nickel Wound .024, .034, .044', 'Made in the U.S.A. for the highest quality and performance'], 'price': '$4.49'}, 'Reviews by similar users': {1: {'verified': False, 'reviewText': "~ I have been using these strings exclusively for the past two or three years and have been happy with their sound, quality, and lifetime.\n~ I am playing jazzy blues using a vintage 1966 Gibson ES 330TD thin-line hollow body processed through a Creamy Wine Limited Edition Fender Blues Junior iii.  The sound I am getting with all tone controls set at neutral (mid-point) and both of the P90 pickups on is fine.  However, I am probably going to step up to the 11/49 medium version of these strings next time to get a slightly fatter sound (without going all the way to the mellow sound provided by the D'Addario Chromes.)\n~ In summary, nice strings at a great price.  Recommended.", 'overall': 5.0, 'summary': 'Bright, Reliable Strings'}, 2: {'verified': True, 'reviewText': 'good product', 'overall': 5.0, 'summary': 'Five Stars'}, 3: {'verified': True, 'reviewText': 'This is a great value pack of the most popular gauge of electric guitar string. Performance, quality at a great price delivered seamlessly by Amazon.', 'overall': 5.0, 'summary': "D'addario exl 10 pack 10 - 46 guage guitar strings"}, 4: {'verified': True, 'reviewText': "Hey jerks, do you play guitar?  Well, if you do, you need strings.  Well, you could be an experimental guitarist playing a stringless guitar.  ...
# **************************************************
#
#  Recommendation Justification:
#
#
# An error occurred during content generation: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '500'}]}, {'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '6s'}]}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 gemini_5shot_justifications = LLM_attribute(reviewers_by_degree, num_product_reviews=5, num_user_reviews=5, num_helpful_reviews=5)
#
# Cell In[49], line 24, in LLM_attribute(users, graph, sleep, print_out, num_product_reviews, num_user_reviews, num_helpful_reviews, **kwargs)
#      20 for user in users:
#      22     data['user'] = user
# ---> 24     product_id, recommendation_info = find_prompt_info(user, num_product_reviews=num_product_reviews, num_user_reviews=num_user_reviews, num_helpful_reviews=num_helpful_reviews)
#      25     if print_out:
#      26         print("*" * 50, "\n")
#
# Cell In[47], line 5, in find_prompt_info(user_id, graph, num_product_reviews, num_user_reviews, num_helpful_reviews, utility_matrix, user_similarity_matrix, item_similarity_matrix, recommendations)
#       3 recommended_product_id = recommendations[user_id][0]
#       4 product_reviews = collect_reviews(user_id, recommended_product_id, similarity='user', num_reviews=num_user_reviews) # review of product by similar user
# ----> 5 item_reviews = collect_reviews(user_id, recommended_product_id, similarity='item', num_reviews=num_product_reviews)  # reviews by user of similar products
#       6 most_helpful_review = find_most_helpful_review(recommended_product_id, num_reviews=num_helpful_reviews)
#       8 product_info = {
#       9     k: v for k, v in G.nodes[recommended_product_id].items() if k in relevant_product_keys
#      10 }
#
# Cell In[28], line 64, in collect_reviews(user_id, product_id, similarity, utility_matrix, item_matrix, user_matrix, graph, num_reviews)
#      52 edges = (
#      53     graph.out_edges(s, data=True)
#      54     if similarity == 'user'  # for user similarity we want out edges
#      55     else graph.in_edges(s, data=True) # and in edges for item similarity
#      56 )
#      57 # iterate through source, target and edge in the edge set of s
#      58 # if similarity is USER, the edge set is the out set of similar users and the target node is product_id
#      59 ## which means the product_id (target_node) is v
#    (...)     62 ## and the target_node is the user_id
#      63 ## which means the the user_id is u
# ---> 64 for u, v, data in edges:
#      65     if similarity == 'user':
#      66         connected_node = v
#
# File c:\Users\bened\anaconda3\envs\SINA-AT3\Lib\site-packages\networkx\classes\reportviews.py:884, in InEdgeDataView.__iter__(self)
#     881 def __iter__(self):
#     882     return (
#     883         self._report(nbr, n, dd)
# --> 884         for n, nbrs in self._nodes_nbrs()
#     885         for nbr, dd in nbrs.items()
#     886     )
#
# File c:\Users\bened\anaconda3\envs\SINA-AT3\Lib\site-packages\networkx\classes\reportviews.py:779, in OutEdgeDataView.__init__.<locals>.<lambda>()
#     776 else:
#     777     # dict retains order of nodes but acts like a set
#     778     nbunch = dict.fromkeys(viewer._graph.nbunch_iter(nbunch))
# --> 779     self._nodes_nbrs = lambda: [(n, adjdict[n]) for n in nbunch]
#     780 self._nbunch = nbunch
#     781 self._data = data
#
# File c:\Users\bened\anaconda3\envs\SINA-AT3\Lib\site-packages\networkx\classes\reportviews.py:779, in <listcomp>(.0)
#     776 else:
#     777     # dict retains order of nodes but acts like a set
#     778     nbunch = dict.fromkeys(viewer._graph.nbunch_iter(nbunch))
# --> 779     self._nodes_nbrs = lambda: [(n, adjdict[n]) for n in nbunch]
#     780 self._nbunch = nbunch
#     781 self._data = data
#
# KeyboardInterrupt:

# %%
gemini_5shot_df = pd.DataFrame(rows)
gemini_5shot_df.head()
# Out:
#              user                                            Product  \
# 0  A2NYK9KWFMJV4Y  CBI MLC LowZ XLR Male to XLR Female Microphone...
# 1  A2NYK9KWFMJV4Y  CBI MLC LowZ XLR Male to XLR Female Microphone...
# 2  A2NYK9KWFMJV4Y  CBI MLC LowZ XLR Male to XLR Female Microphone...
# 3  A2NYK9KWFMJV4Y  CBI MLC LowZ XLR Male to XLR Female Microphone...
# 4  A2NYK9KWFMJV4Y  CBI MLC LowZ XLR Male to XLR Female Microphone...
#
#                             Model  Num Product Reviews  Num User Reviews  \
# 0  gemini-2.5-flash-preview-04-17                    1                 1
# 1  gemini-2.5-flash-preview-04-17                    2                 2
# 2  gemini-2.5-flash-preview-04-17                    3                 3
# 3  gemini-2.5-flash-preview-04-17                    4                 4
# 4  gemini-2.5-flash-preview-04-17                    5                 5
#
#                                        Justification  Num Helpful Reviews
# 0  Based on your experience with gear like mic an...                  NaN
# 1  Based on your interest in musical equipment li...                  NaN
# 2  This CBI microphone cable could be a great add...                  NaN
# 3  Based on your experience with different musica...                  2.0
# 4  Based on your experience valuing dependable ge...                  5.0

# %% [markdown]
# save graph

# %%
with open(os.path.join(graphs_dir, "graph_gemini-5shot.pkl"), 'wb') as f: 
    pickle.dump(G, f)

# %% [markdown]
# # <i> other API approaches </i>

# %% [markdown]
# Through openrouter.
#
# <i> Note: </i> openrouter.ai is useful in that you can make calls to many different LLM APIs through the same service. The downside is that your traffic is routed through openrouter, so that rate limits are applied on ALL calls coming through openrouter, not just ours. If you hit the rate limit, you may need to either change the model to a less popular one, or try making calls directly to the source.

# %%
import requests
import json 
from dotenv import load_dotenv 

env_path = os.path.join(project_dir, ".env") 
load_dotenv(env_path) 

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions", 
    headers={
        "Authorization": f"Bearer {openrouter_api_key}",
        "Content-Type": "application/json" 
    }, 
    data = json.dumps({
        "model": "google/gemini-2.0-flash-exp:free",
        "messages": [
            {
                "role": "user",
                "content": [
                    {
                        "type": "text", 
                        "text": task_prompt
                    }
                ]
            }
        ]
    })
)

print("---Prompt---") 
print(task_prompt)
print("\n---Model Response ---") 
try: 
    result = response.json() 
    message = result['choices'][0]['message']['content'] 
    print(message) 
except Exception as e: 
    print("Error extracting model response:", e) 
    print("Raw response:", response.text)
# Out:
# ---Prompt---
#
# ### TASK DESCRIPTION:
# Your task is to generate short recommendation tips for Amazon users based on information that will be provided to you in follow up prompts.
# The information you will be given is structured in JSON format.
# The structure is as follows:
# {
#     Product: {<key-value pairs providing information on the recommended product>},
#     Reviews by similar users: {
#         <Ranked similarity with user, with 1 being the highest rank>: <review data as key value pairs>{
#             <overall>: <rating this user gave to the product>,
#             <verified>: <if True, this review is known to derive from a trusted source>,
#             <reviewText>: <the text of the review itself>,
#             <summary>: <a brief summary of the review>
#             },
#     Reviews of similar product by user: {<same structure as above. These reviews are of the products most similar to the recommended product, and are written by the recomendee user.>},
#     Helpful review of product: {<same structure as above. This review of the product was voted most helpful by other users.>},
# }
# Your task is to synthesize this information into a short recommendation tip for the product that is customized for this user.
# The next part of the prompt will contain the structured data:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
#
# ---Model Response ---
# Okay, I understand. I'm ready to receive the JSON data and will use it to generate a short, customized recommendation tip for the Amazon user. I will focus on synthesizing the information from the product details, reviews by similar users, the user's reviews of similar products, and the most helpful review. I will aim to create a helpful and persuasive recommendation. Awaiting the data!

# %%
import requests
import json 
from dotenv import load_dotenv 
from openai import OpenAI 

env_path = os.path.join(project_dir, ".env") 
load_dotenv(env_path) 

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

client = OpenAI(
    base_url='https://openrouter.ai/api/v1',
    api_key = openrouter_api_key
)

completion = client.chat.completions.create(
    model="google/gemini-2.0-flash-exp:free", 
    messages=[
        {
            "role": "user", 
            "content": [
                {
                    "type": "text",
                    "text": task_prompt
                }
            ]
        }
    ]
)
try: 
    message = completion.choices[0].message.content 
    print(message) 
except Exception as e: 
    print("Error extracting model response:", e) 
    print("Raw response:", completion.error['message'])
# Out:
# Okay, I understand. I'm ready to receive the JSON data and will synthesize it into a short, personalized recommendation tip for the Amazon user. I will focus on extracting the most relevant information from the provided data to create a concise and helpful tip. I'll pay attention to:
#
# *   **Product details:** Key aspects of the product that might appeal to the user.
# *   **Similar user reviews:** Common themes, positive and negative, from users with similar tastes.
# *   **User's past reviews of similar products:** How the user has reacted to similar items in the past.
# *   **Helpful review:** Key points from the review that others have found most valuable.
#
# Let's begin! I'm eager to see the data.
